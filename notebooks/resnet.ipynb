# %%
# %cd src/
from pathlib import Path
import numpy as np
import math
from itertools import groupby
import h5py
import numpy as np
import unicodedata
import cv2
import torch
from torch import nn
from torchvision.models import resnet50, resnet101, resnet34, resnet18
from torch.autograd import Variable
import torchvision
from data import preproc as pp
from data import evaluation
from torch.utils.data import Dataset
import time
import timm
import torch



class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=128):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

class OCR(nn.Module):

    def __init__(self, vocab_len, hidden_dim, nheads,
                 num_encoder_layers, num_decoder_layers):
        super().__init__()
    
#         self.backbone = timm.create_model('ecaresnet101d', pretrained=True,)
#         del self.backbone.fc
        self.backbone = resnet50(pretrained=False)
        del self.backbone.fc
        
        
#         del self.backbone.classifier, self.backbone.conv_head, self.backbone.bn2,self.backbone.act2,self.backbone.global_pool
        _ = self.backbone.to("cpu")
#         for name,p in self.backbone.named_parameters():
#             if "bn" not in name or "attnpool" in name:
#                 p.requires_grad =  FalseFalse

        # create a default PyTorch transformer
        # create conversion layer
        self.conv = nn.Conv2d(2048, hidden_dim, 1)

        # create a default PyTorch transformer
        self.transformer = nn.Transformer(
            hidden_dim, nheads, num_encoder_layers, num_decoder_layers)

        # prediction heads with length of vocab
        # DETR used basic 3 layer MLP for output
        self.vocab = nn.Linear(hidden_dim,vocab_len)

        # output positional encodings (object queries)
        self.decoder = nn.Embedding(vocab_len, hidden_dim)
        self.query_pos = PositionalEncoding(hidden_dim, .2)

        # spatial positional encodings, sine positional encoding can be used.
        # Detr baseline uses sine positional encoding.
        self.row_embed = nn.Parameter(torch.rand(50, hidden_dim // 2))
        self.col_embed = nn.Parameter(torch.rand(50, hidden_dim // 2))
        self.trg_mask = None
  
    def generate_square_subsequent_mask(self, sz):
        mask = torch.triu(torch.ones(sz, sz), 1)
        mask = mask.masked_fill(mask==1, float('-inf'))
        return mask
    
#     def get_feature(self,x):
#             x = self.backbone.conv_stem(x)
#             x = self.backbone.bn1(x)   
#             x = self.backbone.act1(x)
#             x = self.backbone.blocks(x)
#             return x

    def get_feature(self,x):
        x = self.backbone.conv1(x)
        x = self.backbone.bn1(x)   
        x = self.backbone.relu(x)
        x = self.backbone.maxpool(x)

        x = self.backbone.layer1(x)
        x = self.backbone.layer2(x)
        x = self.backbone.layer3(x)
        x = self.backbone.layer4(x)
        return x

#     def get_feature(self, x):
#         x = self.backbone.forward_features(x)
#         return x


    def make_len_mask(self, inp):
        return (inp == 0).transpose(0, 1)


    def forward(self, inputs, trg):
        # propagate inputs through ResNet-101 up to avg-pool layer
        x = self.get_feature(inputs)

        # convert from 2048 to 256 feature planes for the transformer
        h = self.conv(x)

        # construct positional encodings
        bs,_,H, W = h.shape
        pos = torch.cat([
            self.col_embed[:W].unsqueeze(0).repeat(H, 1, 1),
            self.row_embed[:H].unsqueeze(1).repeat(1, W, 1),
        ], dim=-1).flatten(0, 1).unsqueeze(1)

        # generating subsequent mask for target
        if self.trg_mask is None or self.trg_mask.size(0) != len(trg):
            self.trg_mask = self.generate_square_subsequent_mask(trg.shape[1]).to(trg.device)

        # Padding mask
        trg_pad_mask = self.make_len_mask(trg)

        # Getting postional encoding for target
        trg = self.decoder(trg)
        trg = self.query_pos(trg)
        
        output = self.transformer(pos + 0.1 * h.flatten(2).permute(2, 0, 1), trg.permute(1,0,2), tgt_mask=self.trg_mask, 
                                  tgt_key_padding_mask=trg_pad_mask.permute(1,0))

        return self.vocab(output.transpose(0,1))


def make_model(vocab_len, hidden_dim=256, nheads=4,
                 num_encoder_layers=4, num_decoder_layers=4):
    
    return OCR(vocab_len, hidden_dim, nheads,
                 num_encoder_layers, num_decoder_layers)

"""
Uses generator functions to supply train/test with data.
Image renderings and text are created on the fly each time.
"""

class DataGenerator(Dataset):
    """Generator class with data streaming"""

    def __init__(self, source, split, transform, tokenizer):
        self.tokenizer = tokenizer
        self.transform = transform
        
        self.split = split
        self.dataset = dict()

        with h5py.File(source, "r") as f:
            self.dataset[self.split] = dict()

            self.dataset[self.split]['dt'] = np.array(f[self.split]['dt'])
            self.dataset[self.split]['gt'] = np.array(f[self.split]['gt'])
          
            randomize = np.arange(len(self.dataset[self.split]['gt']))
            np.random.seed(42)
            np.random.shuffle(randomize)

            self.dataset[self.split]['dt'] = self.dataset[self.split]['dt'][randomize]
            self.dataset[self.split]['gt'] = self.dataset[self.split]['gt'][randomize]

            # decode sentences from byte
            self.dataset[self.split]['gt'] = [x.decode() for x in self.dataset[self.split]['gt']]
            
        self.size = len(self.dataset[self.split]['gt'])


    def __getitem__(self, i):
        img = self.dataset[self.split]['dt'][i]
        
        #making image compatible with resnet
#         img = cv2.transpose(img)
        img = np.repeat(img[..., np.newaxis],3, -1).astype("float32")   
#         img = pp.normalization(img).astype("float32")

        if self.transform is not None:
            aug = self.transform(image=img)
            img = aug['image']
            
#             img = self.transform(img)
            
        y_train = self.tokenizer.encode(self.dataset[self.split]['gt'][i]) 
        
        #padding till max length
        y_train = np.pad(y_train, (0, self.tokenizer.maxlen - len(y_train)))

        gt = torch.Tensor(y_train)

        return img, gt          

    def __len__(self):
      return self.size

class Tokenizer():
    """Manager tokens functions and charset/dictionary properties"""

    def __init__(self, chars, max_text_length=128):
        self.PAD_TK, self.UNK_TK,self.SOS,self.EOS = "¶", "¤", "SOS", "EOS"
        self.chars = [self.PAD_TK] + [self.UNK_TK ]+ [self.SOS] + [self.EOS] +list(chars)
        self.PAD = self.chars.index(self.PAD_TK)
        self.UNK = self.chars.index(self.UNK_TK)

        self.vocab_size = len(self.chars)
        self.maxlen = max_text_length

    def encode(self, text):
        """Encode text to vector"""
        text = unicodedata.normalize("NFKD", text).encode("ASCII", "ignore").decode("ASCII")
        text = " ".join(text.split())

        groups = ["".join(group) for _, group in groupby(text)]
        text = "".join([self.UNK_TK.join(list(x)) if len(x) > 1 else x for x in groups])
        encoded = []

        text = ['SOS'] + list(text) + ['EOS']
        for item in text:
            index = self.chars.index(item)
            index = self.UNK if index == -1 else index
            encoded.append(index)

        return np.asarray(encoded)

    def decode(self, text):
        """Decode vector to text"""
        
        decoded = "".join([self.chars[int(x)] for x in text if x > -1])
        decoded = self.remove_tokens(decoded)
        decoded = pp.text_standardize(decoded)

        return decoded

    def remove_tokens(self, text):
        """Remove tokens (PAD) from text"""

        return text.replace(self.PAD_TK, "").replace(self.UNK_TK, "")
# Out:
# /home/mhamdan/seq2seqAttenHTR/Transformer_ocr/src

# %%
import os
import datetime
import string

batch_size = 16
epochs = 200

# define paths
#change paths accordingly
source = 'bentham'
source_path = '../data/{}.hdf5'.format(source)
output_path = os.path.join("..", "output", source)
target_path = os.path.join(output_path, "checkpoint_weights_iam_{}.hdf5".format("dsa"))
os.makedirs(output_path, exist_ok=True)

# define input size, number max of chars per line and list of valid chars
input_size = (1024, 128, 1)
max_text_length = 128
charset_base = string.printable[:95]
# charset_base = string.printable[:36].lower() + string.printable[36+26:95].lower() 

print("source:", source_path)
print("output", output_path)
print("target", target_path)
print("charset:", charset_base)

import torchvision.transforms as T
local_rank = 1
device = torch.device("cuda:{}".format(local_rank))

# transform = T.Compose([
#     T.ToTensor()])
tokenizer = Tokenizer(charset_base)
import albumentations
import albumentations.pytorch



transform_valid = albumentations.Compose(
    [
        albumentations.Normalize(),
        albumentations.pytorch.ToTensorV2()
    ]
)
# Out:
# source: ../data/bentham.hdf5
# output ../output/bentham
# target ../output/bentham/checkpoint_weights_iam_dsa.hdf5
# charset: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
tokenizer = Tokenizer(charset_base)

# %%
model = make_model( vocab_len=tokenizer.vocab_size,hidden_dim=256, nheads=4,
                 num_encoder_layers=4, num_decoder_layers=4)

_ = model.to(device)

# %%
d = torch.load("/home/mhamdan/seq2seqAttenHTR/Transformer_ocr/output/glorious-feather-40/bentham_firstbest_cer.pt", map_location="cuda:1")

# %%
f = {}
for i in d:
    f[i.replace("module.","")] = d[i]

model.load_state_dict(f)
# Out:
# <All keys matched successfully>

# %%
def get_memory(model,imgs):
    x = model.conv(model.get_feature(imgs))
    bs,_,H, W = x.shape
    pos = torch.cat([
            model.col_embed[:W].unsqueeze(0).repeat(H, 1, 1),
            model.row_embed[:H].unsqueeze(1).repeat(1, W, 1),
        ], dim=-1).flatten(0, 1).unsqueeze(1)

    return model.transformer.encoder(pos +  0.1 * x.flatten(2).permute(2, 0, 1))
    

def test(model, test_loader, max_text_length):
    model.eval()
    predicts = []
    gt = []
    imgs = []
    c=0
    with torch.no_grad():
        for batch in test_loader:
            src, trg = batch
            imgs.append(src.flatten(0,1))
            src, trg = src.to(device), trg.to(device)  
            t1 = time.time()
            memory = get_memory(model,src.float())
            out_indexes = [tokenizer.chars.index('SOS'), ]
            for i in range(max_text_length):
                mask = model.generate_square_subsequent_mask(i+1).to(device)
                trg_tensor = torch.LongTensor(out_indexes).unsqueeze(1).to(device)
                output = model.vocab(model.transformer.decoder(model.query_pos(model.decoder(trg_tensor)), memory,tgt_mask=mask))
                out_token = output.argmax(2)[-1].item()
                out_indexes.append(out_token)
#                 if out_token == tok enizer.chars.index('EOS'):
#                     break
            print(time.time()-t1)
            predicts.append(tokenizer.decode(out_indexes))
            gt.append(tokenizer.decode(trg.flatten(0,1)))
            if c==1:
                break
            c+=1
    return predicts, gt, imgs

# %%
test_loader = torch.utils.data.DataLoader(DataGenerator(source_path,'test',transform_valid, tokenizer), batch_size=1, shuffle=False, num_workers=6)

# %%
predicts, gt, imgs = test(model,test_loader , max_text_length)
# Out:
# 0.643765926361084
# 0.653745174407959

# %%
img = torch.rand(1,3,1024,128).to("cuda:1")
trg = torch.randint(1,5,(1,128)).to("cuda:1")

# %%
# %%time
x = model(img,trg)
# Out:
# CPU times: user 303 ms, sys: 19.5 ms, total: 322 ms
# Wall time: 50 ms

# %%
predicts = list(map(lambda x : x.replace('SOS','').replace('EOS',''),predicts))
gt = list(map(lambda x : x.replace('SOS','').replace('EOS',''),gt))

evaluate = evaluation.ocr_metrics(predicts=predicts,
                                  ground_truth=gt,)

# %%
evaluate
# Out:
# array([0.08003765, 0.20241442, 0.70728643])

# %%
evaluate
# Out:
# array([0.07497537, 0.22432195, 0.84280702])

# %%
evaluate
# Out:
# array([0.80593583, 0.95730711, 1.        ])

# %%
evaluate
# Out:
# array([0.69395267, 0.87707289, 1.        ])

# %%
more = predicts.copy()

# %%
less = predicts.copy()

# %%
# less[:3], more[:3]

# %%
predicts[:10]
# Out:
# ['squite unable to explain why he should feel',
#  'meet the Deanes , and as scon as Gny had',
#  'the harges and drank grough to cre ow',
#  "you not killed ! ' Because we know all things , ' the",
#  'with the possibility of fanltty design . " He held',
#  'all due deference , Miss beaue - come off it ! " ',
#  '3t would have been acceptable to all concemed',
#  'to make you understand just what happered',
#  'course of action should be . First to avoid the',
#  'I Stamp Departmentl ) while sally salked at home . ']

# %%
le = 10

# %%
more[:2]
# Out:
# ['Je vous serais reconnaissante de bien vouloir prendre',
#  'cur je dais finourcu mon mariage']

# %%
evaluation.ocr_metrics(predicts=less[:le],
                                  ground_truth=gt[:le])
# Out:
# array([0.01645542, 0.06754902, 0.4       ])

# %%
evaluation.ocr_metrics(predicts=more[:le],
                                  ground_truth=gt[:le])
# Out:
# array([0.06857834, 0.17412465, 0.5       ])

# %%
lless = [v for i,v in enumerate(less) if i not in rem]
gless = [v for i,v in enumerate(gt) if i not in rem]
mmore = [v for i,v in enumerate(more) if i not in rem]

# %%
evaluation.ocr_metrics(predicts=lless,
                                  ground_truth=gless),evaluation.ocr_metrics(predicts=mmore,
                                  ground_truth=gless)
# Out:
# (array([0.03315958, 0.08458639, 0.34398496]),
#  array([0.05809512, 0.15275311, 0.54135338]))

# %%
rem = []
for i,v in enumerate(gt):
    nm = evaluation.ocr_metrics(predicts=[predicts[i]],
                                  ground_truth=[v])    
    print("gt", v)
    print("less", predicts[i], nm)
    print("-"*50)
# Out:
# gt ai regle regulierement les interets .
# less ai regle regulierement les interets .  [0. 0. 0.]
# --------------------------------------------------
# gt le cas echeant pour qu ' une nouvelle ristourne me soit accordee .
# less le cas echerant pour qu ' une nouvelle ristourne un soit accordie .  [0.05882353 0.23076923 1.        ]
# --------------------------------------------------
# gt concernant votre service de telephonie . Je m ' y suis en effet inscrite il y a
# less concernant votre service de telephonie . Je m ' il suis en effet in effet inscitite d l y a [0.16483516 0.3        1.        ]
# --------------------------------------------------
# gt Je vous prie d ' agreer , Madame , Monsieur , l ' expression de mes
# less Je vous prie d ' agreer , Madame , Monsieur , l ' expression de mes [0. 0. 0.]
# --------------------------------------------------
# gt J ' ai pu relever differents dommages : peinture et moquette abimees et
# less J ' ai pu relever differents dommages : perture etur ature noqueture et noquett abimeees et [0.26373626 0.375      1.        ]
# --------------------------------------------------
# gt scolaires , mais ma demande est restee sans effet .
# less scolaires , mais ma demande est restee sans effet .  [0. 0. 0.]
# --------------------------------------------------
# gt souhait de diminuer mes versements sur mon plan epargne
# less souhait de diminuer mes versements sur mon plan epargne [0. 0. 0.]
# --------------------------------------------------
# gt Dans l ' attente d ' une reponse rapide de votre
# less Dans l ' attente d ' une reponse rapide de votre [0. 0. 0.]
# --------------------------------------------------
# gt laquelle je vous demande une remise gracieuse
# less Caquelle je vous demande une remise gracieuse [0.02222222 0.14285714 1.        ]
# --------------------------------------------------
# gt etendre vos prestations a mon logement .
# less etendre vos prestations a mon logement .  [0. 0. 0.]
# --------------------------------------------------
# gt de la regler dans son integralite dans le temps imparti .
# less de la regles dans son integralite dans le temps importe .  [0.05172414 0.18181818 1.        ]
# --------------------------------------------------
# gt Dans cette attente ,
# less Dans cette attente ,  [0. 0. 0.]
# --------------------------------------------------
# gt demande . Ma reference client est : GFLYX65 .
# less demande . Ma reference client est : GFLYXX165 .  [0.04166667 0.11111111 1.        ]
# --------------------------------------------------
# gt demande de resiliation expediee le mois
# less demande de resiliation expediee le moist [0.025      0.16666667 1.        ]
# --------------------------------------------------
# gt commande du 12 / 12 / 2006 trois paires de chaussettes grises
# less commande du 12 1212 / 2006 trois paires de chaussettes gasses [0.06557377 0.25       1.        ]
# --------------------------------------------------
# gt Le montant de ma facture est trop eleve .
# less Le montant de ma facture est trop eleve .  [0. 0. 0.]
# --------------------------------------------------
# gt mes sinceres salutations .
# less mes sinceres salutations .  [0. 0. 0.]
# --------------------------------------------------
# gt Je me permets de vous ecrier car je souhaiterais
# less le me permets de vous ecrire car je souhaiterais [0.0625     0.22222222 1.        ]
# --------------------------------------------------
# gt salutations .
# less salutations .  [0. 0. 0.]
# --------------------------------------------------
# gt selon les indications donnees dans ma precedente lettre
# less selon les indications donnees dans ma precedente lettre [0. 0. 0.]
# --------------------------------------------------
# gt Je vous ecrit pour vous signaler un changement
# less Je vous ecrit pour vous signaler un changement [0. 0. 0.]
# --------------------------------------------------
# gt un PEA et de gerer au mieux mes interets
# less un PE1 et de gerer au mieux mes interets [0.025      0.11111111 1.        ]
# --------------------------------------------------
# gt que vous me proposez . Est - ce que vous pourriez me repondre dans les
# less que vous me proposez . Est - ce que vous pourriez me repondre dans les [0. 0. 0.]
# --------------------------------------------------
# gt voudrais donc connaitre la marche a suivre pour devenir l ' une
# less voudrais donc connaitre la marche a suivre pour devenir l ' une [0. 0. 0.]
# --------------------------------------------------
# gt et je me tiens a votre disposition pour vous rencontrer si
# less et je me tiens a votre disposition pour vous rencontrer si [0. 0. 0.]
# --------------------------------------------------
# gt mon domicile .
# less mon domicile .  [0. 0. 0.]
# --------------------------------------------------
# gt mes coordonnees personnelles n ' ont pas encore ete modifiees
# less mes coordonnees personnelles n ' ont pas encore ete modifiees [0. 0. 0.]
# --------------------------------------------------
# gt Etant donne les horaires de travail contraignants , je souhaiterai
# less Etant donne mes horaires de trouval contraignants , je souhaiterai [0.06060606 0.2        1.        ]
# --------------------------------------------------
# gt Merci pour votre cooperation future .
# less Merci pour votre comperation future .  [0.02631579 0.16666667 1.        ]
# --------------------------------------------------
# gt resultat de l ' expertise le plus vite possible .
# less resultat de l ' expertise le plus vite possible .  [0. 0. 0.]
# --------------------------------------------------
# gt Pourriez m ' envoyer des documents repondant a mes interrogations .
# less Pourriez m ' envoyer des documents repondant a mes interagations .  [0.02941176 0.09090909 1.        ]
# --------------------------------------------------
# gt par la suite , le gain de temps serait plus appreciable .
# less par la suite , le gain de temps serait plus appreciable .  [0. 0. 0.]
# --------------------------------------------------
# gt numeros du mois de septembre que je n ' avais pas
# less numero du mois de sepembre que je n ' avais pas [0.04081633 0.18181818 1.        ]
# --------------------------------------------------
# gt veux que mon compte soit ferme dans les meilleurs delais , je vous
# less eux que mon compte soit fame dans les meilleurs delais , je vous [0.04545455 0.15384615 1.        ]
# --------------------------------------------------
# gt de ma consideration distinguee .
# less de ma consideration distinguee .  [0. 0. 0.]
# --------------------------------------------------
# gt Je vaisz prochainement me marier , j ' aimerai
# less Je vais prochainement me marier , j ' aimerai [0.02173913 0.11111111 1.        ]
# --------------------------------------------------
# gt j ' espere que vous pourrez repondre rapidement a mes
# less j ' espere que vous pourrez repondre rapidement a mes [0. 0. 0.]
# --------------------------------------------------
# gt mes sentiments les plus respectueux .
# less mes sentiments les plus respectueux .  [0. 0. 0.]
# --------------------------------------------------
# gt demenage et que ma nouvelle adresse est la suivante :
# less demenage et que ma nouvelle adresse est la suivante :  [0. 0. 0.]
# --------------------------------------------------
# gt telephonique , je vous prie de bien vouloir noter
# less telephonique , je vous prie de bien vouloir noter [0. 0. 0.]
# --------------------------------------------------
# gt d ' art ( tableaux ) qui m ' avaient ete leguees .
# less d ' aut ( tableaux ) qui m ' avaient ete lispuees .  [0.07692308 0.15384615 1.        ]
# --------------------------------------------------
# gt En effet , j ' ai brise la porte vitree d ' un magasin en
# less En effet , j ' ai brise la perte vitree d ' un magasin en [0.01754386 0.06666667 1.        ]
# --------------------------------------------------
# gt concernant les contrats d ' assurances vie ?
# less concernant les contrats d ' assurances vie ?  [0. 0. 0.]
# --------------------------------------------------
# gt Dans l ' attente d ' une reponse favorable de votre
# less Dans l ' attente d ' une reponse favorable de votre [0. 0. 0.]
# --------------------------------------------------
# gt Par cette lettre , je souhaite vous informer
# less Par cette lettre , je souhaite vous informer [0. 0. 0.]
# --------------------------------------------------
# gt Dans ces conditions , je vous serai gre de bien vouloir
# less Dans ces conditions , je vous serai gre de bien vouloir [0. 0. 0.]
# --------------------------------------------------
# gt Dans l ' attente de votre courrier , je vous prie de croire , madame ,
# less Dans l ' attente de votre courrier , je vous prie de croirire , de croirire , madame ,  [0.18390805 0.21052632 1.        ]
# --------------------------------------------------
# gt Veuillez recevoir , Madame , Monsieur , mes sinceres salutations .
# less Veuillez recevoir , Madame , Monsieur , mes sinceres salutations .  [0. 0. 0.]
# --------------------------------------------------
# gt commande , je vous remercie et vous prie de
# less commande , je vous remercie et vous prie de [0. 0. 0.]
# --------------------------------------------------
# gt part ,
# less part ;  [0.14285714 0.5        1.        ]
# --------------------------------------------------
# gt J ' estime ainsi que les garanties que vous m ' aviez donnees lors de la souscription
# less J ' estime ainsi que les ganations que vous m ' avez donnez donnees lors donnees lois dons de lois de lons de la sous de la [0.41463415 0.48148148 1.        ]
# --------------------------------------------------
# gt logement , je voudrais ainsi passer de 60 a 45 euros .
# less logement , je voudrais ainsi passer de 60 a 45 euros .  [0. 0. 0.]
# --------------------------------------------------
# gt veuillez agreer , Monsieur , l ' expression de mes
# less veuillez agreer , Monsieur , l ' expression de mes [0. 0. 0.]
# --------------------------------------------------
# gt de vos produits . J ' avais d ' ailleurs passe commande
# less de vos produits . J ' avais d ' ailleurs passe commande [0. 0. 0.]
# --------------------------------------------------
# gt J ' ai commande il y a huit jours 50 actions EDF et
# less J ' ai commande il y a trait pours 50 actions EDOr et [0.11320755 0.23076923 1.        ]
# --------------------------------------------------
# gt Donc je vous prie de bien vouloir me rembourser
# less Donc je vous prie de bien vouloir me rembourser [0. 0. 0.]
# --------------------------------------------------
# gt Je vous ai fait parvenir un courrier le 20 Novembre
# less Je vous ai fait parvenir un courrier le 20 Movembre [0.01960784 0.1        1.        ]
# --------------------------------------------------
# gt mon nombre d ' actions boursieres afin d ' augmenter
# less mon nombre d ' actions boursieres afin d ' augmenter [0. 0. 0.]
# --------------------------------------------------
# gt Je me permets de vous ecrire pour vous faire part de mon insatisfaction
# less Je me permets de vous ecrire pour vous faire part de mon insatisfaction [0. 0. 0.]
# --------------------------------------------------
# gt sollicite donc pour un rendez - vous .
# less sollicite donc pour un rondez - vous .  [0.02564103 0.125      1.        ]
# --------------------------------------------------
# gt ma derniere commande passe le 01 / 12 / 2006 . Je
# less ma derniere commande passe le 01 / 12 posse . Je [0.12244898 0.16666667 1.        ]
# --------------------------------------------------
# gt cinquante CD vierges . La reference du produit est :
# less cinquante CD vierges . Ma reference du produit est :  [0.01886792 0.1        1.        ]
# --------------------------------------------------
# gt Je soussigne Eugene Violette desire cloturer mes
# less Je soussigne augene Viollette desire cloturer mes [0.04081633 0.28571429 1.        ]
# --------------------------------------------------
# gt Je vous informe par la presente de mon demenagement et je vous
# less Je vous informe par la presente de mon demenagement et je vous [0. 0. 0.]
# --------------------------------------------------
# gt l ' expression de mes sinceres salutations .
# less l ' expression de mes sinceres salutations .  [0. 0. 0.]
# --------------------------------------------------
# gt Je vous serais gre de bien vouloir mandater un
# less Je vous serais gre de bien vouloir mondater un [0.02173913 0.11111111 1.        ]
# --------------------------------------------------
# gt des actions en bourse pouvant etre incorpores
# less des actions en bourse pouvant etre murprees [0.13333333 0.14285714 1.        ]
# --------------------------------------------------
# gt Je viens , par la presente , proceder
# less Je viens , par la presente , procedes [0.02702703 0.125      1.        ]
# --------------------------------------------------
# gt 04 92 48 88 30 .
# less 04 92 48 88 30 .  [0. 0. 0.]
# --------------------------------------------------
# gt Mon numero de cliente est le suivant ADMJZ82 et cela
# less Mon numero de cliente cest le suivant MA TIF32 et cela [0.12962963 0.27272727 1.        ]
# --------------------------------------------------
# gt Merci d ' en prendre note et d ' effectuer les mises a jours de mon
# less Merci d ' en prendre note et d ' effectuer les mises a jours de mon [0. 0. 0.]
# --------------------------------------------------
# gt le paiement de mon pret .
# less le Baiement de mon bet .  [0.11538462 0.33333333 1.        ]
# --------------------------------------------------
# gt sont elevees et a cela s ' ajoutent un loyer mensuel ( 500 ) ainsi que
# less sont elevees et a cela s ' ajoutant un loyer mensuel ( 500 ) ainsi que [0.01428571 0.0625     1.        ]
# --------------------------------------------------
# gt 2006 me parait anormalement elevee compte tenu de ma consommation
# less 2006 ma parait anomalement elevee compte tenu de mptenu de ma consommation [0.16216216 0.33333333 1.        ]
# --------------------------------------------------
# gt Suite aux vents forts qui ont souffles sur le departement
# less Suite aux vents forts qui ont souffles sur le departement [0. 0. 0.]
# --------------------------------------------------
# gt En vous remerciant de l ' interet que vous portez a ma
# less En vous remerciant de l ' interet que vous portez a ma [0. 0. 0.]
# --------------------------------------------------
# gt La demande de chaussettes a en effet atteint au niveau si eleve qu ' il nous faut
# less la demande de chassattes a en effet atteint sur sur virau si elever si si elee qu ' il ilais fait [0.28865979 0.52380952 1.        ]
# --------------------------------------------------
# gt N ' ayant eu aucune nouvelle de votre part je tiens
# less N ' Ayant en aucune nouvelle de votre part je tiens [0.03921569 0.18181818 1.        ]
# --------------------------------------------------
# gt chien de mes voisins .
# less chien de mes voisins .  [0. 0. 0.]
# --------------------------------------------------
# gt Dans l ' attente d ' une reponse de votre part , je vous prie
# less Dans l ' attente d ' une reponse de votre part , je vous prie [0. 0. 0.]
# --------------------------------------------------
# gt  ( commande n 226G 450X ) , sur votre site internet , le 10 decembre
# less Commande n 226 4501 ) , sur votre site intenet , le 10 decembre [0.10294118 0.33333333 1.        ]
# --------------------------------------------------
# gt Je viens de subir un degat des eaux dans mon habitation .
# less Je viens de subir un degat des eaux dans mon habitation .  [0. 0. 0.]
# --------------------------------------------------
# gt conjoint a l ' adresse ci - dessus mentionnee .
# less conjoint a l ' adresse ci - dessus mentionnee .  [0. 0. 0.]
# --------------------------------------------------
# gt degradation des conditions de vie dans mon immeuble .
# less degadation des conditions de vie dans mon nurceuse .  [0.12962963 0.22222222 1.        ]
# --------------------------------------------------
# gt Malgre mes demarches a l ' amiable , la situation ne
# less Malgre mes demarches a l ' amiable , la situation ne [0. 0. 0.]
# --------------------------------------------------
# gt la reference ci dessus a subi un degat des eaux le 26 decembre 2006 .
# less la reference ai dessus a subi un degat des eaux le 26 decembre le 26 decembre 20 dec lo decembre 2006 .  [0.33653846 0.36363636 1.        ]
# --------------------------------------------------
# gt me faire parvenir vos horaires d ' accueil du
# less me faire parvenir vos horaires d ' accueil du [0. 0. 0.]
# --------------------------------------------------
# gt la prise en compte de cette modification , et vous
# less la prise en compte de cette modification , et vous [0. 0. 0.]
# --------------------------------------------------
# gt Je reprends contact avec vous pour recevoir
# less Je reprends contact avec vous pour recevoir [0. 0. 0.]
# --------------------------------------------------
# gt En esperant une gestion rapide du sinistre , je vous
# less En esperant une gestion rapide du sinistre , je vous [0. 0. 0.]
# --------------------------------------------------
# gt familiale , a compter du 1 janvier 2007 mes coordonnees
# less familiale , a compter du 1 janvier 2007 mes coordonnees [0. 0. 0.]
# --------------------------------------------------
# gt J ' ai constate que la source de cette nuisance a ete
# less J ' ai constate que la souce de cette nuisance a ete [0.01886792 0.08333333 1.        ]
# --------------------------------------------------
# gt Je suis assujettie a l ' impot sur le revenu , comme
# less Je suis assujettrie a l ' impot sur le revenu , comme [0.01886792 0.08333333 1.        ]
# --------------------------------------------------
# gt Je voudrais recevoir de la documentation
# less Je voudrais recevoir de les documentation [0.04878049 0.16666667 1.        ]
# --------------------------------------------------
# gt concernant les divers contrats d ' assurances
# less concerment les divers contres d ' assurances [0.08888889 0.28571429 1.        ]
# --------------------------------------------------
# gt contrats proposes par votre agence .
# less contrats proposes par votre agence .  [0. 0. 0.]
# --------------------------------------------------
# gt En esperant que vous interviendrez le plus rapidement possible afin de
# less En esperant que vous interniendrez le plus rapidement possible afin de [0.01428571 0.09090909 1.        ]
# --------------------------------------------------
# gt commandees precedemment
# less commandees precedement [0.04347826 0.5        1.        ]
# --------------------------------------------------
# gt salutations .
# less salutations .  [0. 0. 0.]
# --------------------------------------------------
# gt Recevez madame monsieur mes salutations
# less Recevez madame monsieur mes salutations [0. 0. 0.]
# --------------------------------------------------
# gt cinq fois votre service apres - vente d ' ailleurs difficile a joindre , pour regler
# less Cinfois votre service apres - vente d ' ailleurs dieurs diteus difficicile a joindindr dindre , pour reglie [0.28037383 0.44444444 1.        ]
# --------------------------------------------------
# gt Ma Grand - mere m ' a donne 1500 euros en me recommandant
# less Ma trand mere m ' a donne 1500 euro en me recommandant [0.07017544 0.23076923 1.        ]
# --------------------------------------------------
# gt soit 6 lots de 50 CD vierges , au total .
# less soit 6 lots de 50 CD vierges , au total .  [0. 0. 0.]
# --------------------------------------------------
# gt pas au type de contrat que j ' ai souscrit .
# less pas au type de contrat que j ' ai souscrit .  [0. 0. 0.]
# --------------------------------------------------
# gt au titre de la responsabilite civile .
# less au titre de la responsabilite civile .  [0. 0. 0.]
# --------------------------------------------------
# gt Je me permet de vous ecrire car , suite a la
# less Je me permet de vous ecrire car , suite a la [0. 0. 0.]
# --------------------------------------------------
# gt Ayant verifie par telephone qu ' elle n ' avait pas encore ete
# less Ayant verifie par telephone quelle n ' evait pas encore ete [0.06451613 0.30769231 1.        ]
# --------------------------------------------------
# gt salutations distinguees .
# less salutations distinguees [0.11538462 0.33333333 1.        ]
# --------------------------------------------------
# gt concernant vos contrats d ' assurance vie , en effet
# less concernant vos contrats d ' assurance vie , en effet [0. 0. 0.]
# --------------------------------------------------
# gt recus .
# less reclus .  [0.11111111 0.5        1.        ]
# --------------------------------------------------
# gt a un contrat d ' assurance vie .
# less un contrat d ' assurance vie .  [0.06060606 0.125      1.        ]
# --------------------------------------------------
# gt Pour ces differentes raisons , je vous saurai gre d ' echelonner
# less Pour ces differentes raisons , je vous sauvai gre d ' echelonner [0.015625   0.08333333 1.        ]
# --------------------------------------------------
# gt profonde consideration .
# less profonde consideration .  [0. 0. 0.]
# --------------------------------------------------
# gt distinguees .
# less distinguees .  [0. 0. 0.]
# --------------------------------------------------
# gt Donc je vous fait part une nouvelle fois que je ne veux plus recevoir
# less Donc je vous fait part une nouvelle fois que je ne me reux plus rensir [0.11428571 0.2        1.        ]
# --------------------------------------------------
# gt Je me permets de vous ecrire car je suis mecontente
# less Je me permets de vous ecrire car je suis me contente [0.01923077 0.18181818 1.        ]
# --------------------------------------------------
# gt Par la presente , je vous adresse une commande suite a
# less Par la presente , je vous adresse un commande suite a [0.01851852 0.09090909 1.        ]
# --------------------------------------------------
# gt reglement pour la presente commande de cinquante CD
# less reglement pour la presente commande de cinquante CD [0. 0. 0.]
# --------------------------------------------------
# gt de mes salutations distinguees .
# less de mes salutations distingues .  [0.03030303 0.2        1.        ]
# --------------------------------------------------
# gt Merci de me confirmer que vous avez bien pris en compte
# less Merci de me confirmer que vous avez bien pris en compte [0. 0. 0.]
# --------------------------------------------------
# gt dossier . Mon numero de reference client est le suivant : ARNRH57 .
# less dossier . Mon numero de reference client est le suivant : AANANTH457 .  [0.07042254 0.07692308 1.        ]
# --------------------------------------------------
# gt Ma reference client : BXJUT96
# less Ma reference client : BXJUT96 [0. 0. 0.]
# --------------------------------------------------
# gt En effet , je suis genee par de nombreuses nuisances
# less En effet , je suis jenee par de nombreuses nuisances [0.01923077 0.1        1.        ]
# --------------------------------------------------
# gt Je vous serais reconnaissante de prendre en compte
# less Je vous serais reconnaissante de prendre en compte [0. 0. 0.]
# --------------------------------------------------
# gt en compte ma demande et vous prie d ' agreer ,
# less en compte ma demande et vous prie d ' agreer ,  [0. 0. 0.]
# --------------------------------------------------
# gt de substitution .
# less de salutation .  [0.33333333 0.33333333 1.        ]
# --------------------------------------------------
# gt Vivement interessee par certains de vos produits ,
# less Vivement interessee par certains de vos produits ,  [0. 0. 0.]
# --------------------------------------------------
# gt commande effectuee chez vous . En effet , je souhaite -
# less commande effectuee chez vous . En effet , je souhaite -  [0. 0. 0.]
# --------------------------------------------------
# gt de m ' envoyer un courrier m ' indiquant vos horaires d ' accueil
# less de m ' envoyer un courrier m ' indiquant vos horaires d vos horaires d ' accueil [0.1875     0.17647059 1.        ]
# --------------------------------------------------
# gt aucune reponse de votre part . Je souhaiterais qu ' on donne
# less aucune reponse de votre part . Je souhaiterais qu ' on donne [0. 0. 0.]
# --------------------------------------------------
# gt du premier tiers provisionnel des impots en totalite .
# less du premier tiers provisionnel des impots en totalite .  [0. 0. 0.]
# --------------------------------------------------
# gt part ,
# less part [0.42857143 0.5        1.        ]
# --------------------------------------------------
# gt de mes sentiments distinguees .
# less de mes sentiments distingues .  [0.03125 0.2     1.     ]
# --------------------------------------------------
# gt modification .
# less modification .  [0. 0. 0.]
# --------------------------------------------------
# gt Je vous remercie de l ' attention que vous porterez
# less Je vous remercie de l ' attention que vous parterez [0.01960784 0.1        1.        ]
# --------------------------------------------------
# gt d ' un compte , dans votre agence .
# less d ' un compte , dans votre agence .  [0. 0. 0.]
# --------------------------------------------------
# gt me tourner vers vos concurrents .
# less me tourner vers vos concurrents .  [0. 0. 0.]
# --------------------------------------------------
# gt Voici mon second courrier pour vous
# less Voien mon second courrier pour vous [0.05714286 0.16666667 1.        ]
# --------------------------------------------------
# gt Je souhaiterais commander a votre entreprise un lot de
# less Je souhaiterais commander a votre entreprise un lot de [0. 0. 0.]
# --------------------------------------------------
# gt Veuillez trouver ci - joint un cheque pour le reglement du surplus .
# less Veuillez trouver ci - joint un cheque pour le reglement du surplus .  [0. 0. 0.]
# --------------------------------------------------
# gt Madame , Monsieur l ' expression de mes salutations
# less Madame , Monsieur l ' expression de mes salutations [0. 0. 0.]
# --------------------------------------------------
# gt Je vous prie d ' agreer , Madame , Monsieur , l ' assurance
# less Je vous prie d ' agreer , Madame , Monsieur , l ' assurance [0. 0. 0.]
# --------------------------------------------------
# gt l ' expression de mes sentiments les meilleurs .
# less l ' expression de mes sentiments les meilleurs [0.06122449 0.11111111 1.        ]
# --------------------------------------------------
# gt Je vous joins le certificat de cession et vous rappelle ma reference
# less Je vous joins le certificat de cession et vous rappelle ma reference [0. 0. 0.]
# --------------------------------------------------
# gt meme aimerions souscrire un contrat d ' assurance vie .
# less meme aimerions souscrire un contrat d ' assurance vie .  [0. 0. 0.]
# --------------------------------------------------
# gt du service que vous proposez , mauvaise reception a l ' accueil ainsi que
# less du service que vous proposez , mamaise reception a l ' accueil ainsi que [0.02739726 0.07142857 1.        ]
# --------------------------------------------------
# gt distinguees .
# less distinguees .  [0. 0. 0.]
# --------------------------------------------------
# gt Veuillez agreer mes sinceres salutations ,
# less Veuillez agreer mes sinceres salutations ,  [0. 0. 0.]
# --------------------------------------------------
# gt salutations distinguees .
# less salutations distinguees .  [0. 0. 0.]
# --------------------------------------------------
# gt concernant les actions boursieres que vous
# less concernant 1es actions boursieres que vous [0.02380952 0.16666667 1.        ]
# --------------------------------------------------
# gt l ' article que j ' avais choisi correspondant a un
# less l ' article que j ' avais choisi correspondant a un [0. 0. 0.]
# --------------------------------------------------
# gt ces dites actions .
# less mes dites achions .  [0.1 0.5 1. ]
# --------------------------------------------------
# gt client : SWFBR24 .
# less client : sUFBR24 .  [0.10526316 0.25       1.        ]
# --------------------------------------------------
# gt mes respectueuses salutations .
# less mes respectueuses salutations .  [0. 0. 0.]
# --------------------------------------------------
# gt effet , la perte brutale de mon emploi , unique source de
# less effet , la perte butale de mon emploi , unque sarce de [0.07017544 0.25       1.        ]
# --------------------------------------------------
# gt Dans l ' attente de votre reponse , je vous
# less Dans l ' attente de votre reponse , je vous [0. 0. 0.]
# --------------------------------------------------
# gt reference dans l ' objet .
# less reference dans l ' objet :  [0.03703704 0.16666667 1.        ]
# --------------------------------------------------
# gt ce changement tout en restant dans les delais que nous avions
# less Ce changement tout en retant dans les delais que nons aviens [0.06557377 0.36363636 1.        ]
# --------------------------------------------------
# gt Je porte a votre connaissance le fait que ce matin j ' ai
# less Je porte a votre connaissance le fait que ce mation j ' ai [0.01724138 0.07692308 1.        ]
# --------------------------------------------------
# gt de retructuration de l ' entreprise qui etait deficitaire .
# less de rentruction de l ' entreprise qui etait defictaire .  [0.1 0.2 1. ]
# --------------------------------------------------
# gt se tassent dans le bout de la chaussure et me font souffrir
# less se taissent dans le bont de la chaussire et me fait souffin [0.11864407 0.41666667 1.        ]
# --------------------------------------------------
# gt la remise la plus importante possible de cet impot .
# less la remise la plus importante possible de cet impot .  [0. 0. 0.]
# --------------------------------------------------
# gt d ' aboyer jour et nuit .
# less d ' aboyer jour et nuit .  [0. 0. 0.]
# --------------------------------------------------
# gt Veuillez recevoir Madame et Monsieur
# less Veuillez recevoir cladame et Monsieur [0.05405405 0.2        1.        ]
# --------------------------------------------------
# gt Je vous prie de croire , Madame , Monsieur , en l ' expression
# less Je vous prie de croire , Madame , Monsieur , en l ' expression [0. 0. 0.]
# --------------------------------------------------
# gt quelles sont les conditions d ' utilisations ?
# less quelles sont les conditions d ' utilisations ?  [0. 0. 0.]
# --------------------------------------------------
# gt Je souhaiterais donc etre remboursee des
# less Je souhaiterais donc etre remboursee des [0. 0. 0.]
# --------------------------------------------------
# gt Je vous prie de recevoir Madame , Monsieur
# less Je vous prie de recevoir Madame , Monsieur [0. 0. 0.]
# --------------------------------------------------
# gt votre , je ne suis plus satisfait de ce qu ' elle ne propose et j ' aimerais
# less votre , je ne suis plus satisfait de ce qui ' elle me propose et j ' aimerais [0.02597403 0.11111111 1.        ]
# --------------------------------------------------
# gt je souhaiterais m ' abonner a votre revue " Charite Bushido " .
# less je souhaiterais m ' abonner a votre revue " Detarite " Dettarite . Petharite . Busthidthidididd ?  [0.39795918 0.41176471 1.        ]
# --------------------------------------------------
# gt Je voudrais modifier ma commande du 9 decembre
# less Je voudrais modifier ma commande du 9 decembre [0. 0. 0.]
# --------------------------------------------------
# gt defectueux . En effet , une partie de l ' ecran s ' affiche en rose .
# less defectueus . En effet , une partie de l ' avan s ' afficle en s ' afficle en ros .  [0.24096386 0.38095238 1.        ]
# --------------------------------------------------
# gt ma demande .
# less ma demande .  [0. 0. 0.]
# --------------------------------------------------
# gt Merci de resilier mon contrat d ' assurance auto
# less Merci de resilier mon contrat d ' assurance auto [0. 0. 0.]
# --------------------------------------------------
# gt En consequence , je vous demande de verifier le fonctionnement de
# less En consequence , je vous demande de verifier le fonctionnement de [0. 0. 0.]
# --------------------------------------------------
# gt Malheureusement , ma situation financiere m ' empeche tout a fait de regler
# less Malheureusement , ma situation financiere m ' empecle tout a fait de regler .  [0.05128205 0.14285714 1.        ]
# --------------------------------------------------
# gt distinguees .
# less distinguees .  [0. 0. 0.]
# --------------------------------------------------
# gt question dans mon dossier . J ' ai achete un appartement avec mon conjoint a
# less question dans mon dossier . J ' ai achete un appartement avec mont avec mon con conjoint a [0.15555556 0.16666667 1.        ]
# --------------------------------------------------
# gt une nuisance sonore due aux aboiements du
# less une nuisance sonore clie aux aboriements au [0.11627907 0.42857143 1.        ]
# --------------------------------------------------
# gt tout travaux ?
# less taurt Travanse ?  [0.35294118 0.66666667 1.        ]
# --------------------------------------------------
# gt Suite a la vente de mon vehicule , je vous demande de resilier
# less Suite a la vente de mon vehicule , je vous demande de resilier [0. 0. 0.]
# --------------------------------------------------
# gt CH45 - 02 ) . En esperant que vous pourrez
# less CH45 - 02 ) . En esperent que vous pourrez [0.02380952 0.1        1.        ]
# --------------------------------------------------
# gt les demarches a realiser pour le fonctionnement de mon assurance
# less les demarches a raaliser pour le fonctionnement de mon assurance [0.015625 0.1      1.      ]
# --------------------------------------------------
# gt qui est restee sans reponse .
# less qui est restee sans reponse .  [0. 0. 0.]
# --------------------------------------------------
# gt je vous demande d ' augmenter par deux les
# less je vous demande d ' augmenter par deux les [0. 0. 0.]
# --------------------------------------------------
# gt que m ' aviez conseillees et etant donne le cours
# less que vous m ' aviez conseillees et etant donne le cours [0.09259259 0.09090909 1.        ]
# --------------------------------------------------
# gt construire , aucune reponse ne m ' est
# less construlive , aucune reponse ne m ' est [0.05128205 0.125      1.        ]
# --------------------------------------------------
# gt Ayant perdu mon emploi dans les jours precedents , je ne peux
# less Ayant perdu mon emploi dans les jours precedents , je ne peux [0. 0. 0.]
# --------------------------------------------------
# gt Veuillez agreer , Madame , Monsieur , mes salutations distinguees ,
# less Veuillez agreer , Madame , Monsieur , mes salutations distingues ,  [0.01470588 0.09090909 1.        ]
# --------------------------------------------------
# gt fois .
# less fois .  [0. 0. 0.]
# --------------------------------------------------
# gt Je vous prie de recevoir Madame ,
# less Je vous prie de recevoir Madame ,  [0. 0. 0.]
# --------------------------------------------------
# gt 60 a 45 euros par mois ? Car mon endettement est devenu
# less 60 a 45 euros par mois ? Car mon endettement est devenu [0. 0. 0.]
# --------------------------------------------------
# gt Je vous prie d ' agreer , Madame , Monsieur , l ' expression
# less Je vous prie d ' agreer , Madame , Monsieur , l ' expression [0. 0. 0.]
# --------------------------------------------------
# gt mes etudes ( d ' ici cinq ans ) , avec un risque minimal et une
# less mes etudes / d ' ici cinques ) avec un risque avec un risque aiminimmal et unet unune [0.31764706 0.5        1.        ]
# --------------------------------------------------
# gt Dans l ' attente de votre reponse , je vous prie d ' agreer , Monsieur ,
# less Dans l ' attente de votre reponse , je vous prie d ' agreer , Monsieur , Monsieur ,  [0.13095238 0.10526316 1.        ]
# --------------------------------------------------
# gt de votre part une remise a titre gracieux .
# less de votre part une remise a litre gracieux .  [0.02272727 0.11111111 1.        ]
# --------------------------------------------------
# gt de vous demander de bien vouloir me faire part du
# less de vous demander de bien vouloir me faire part du [0. 0. 0.]
# --------------------------------------------------
# gt sinceres salutations .
# less sinceres salutations .  [0. 0. 0.]
# --------------------------------------------------
# gt sentiments distingues .
# less sentiments distingues .  [0. 0. 0.]
# --------------------------------------------------
# gt envisager une date de debut de travaux .
# less envisager une date de debut de travaux [0.07317073 0.125      1.        ]
# --------------------------------------------------
# gt Dans l ' attente , veuillez agreer mes salutations les plus distingues .
# less Dans l ' attente , veuillez agreer mes salutations les plus plus distingues .  [0.06410256 0.07142857 1.        ]
# --------------------------------------------------
# gt Monsieur , mes salutations .
# less Monsieur , mes salutations .  [0. 0. 0.]
# --------------------------------------------------
# gt cinquante compact - disques vierges de la reference :
# less cinquante compact , disques vierges de la reference :  [0.01851852 0.11111111 1.        ]
# --------------------------------------------------
# gt Pourriez - vous me faire parvenir un constat de degat des
# less Pourriez - vous me faire parvenir un constat de desait des [0.03448276 0.09090909 1.        ]
# --------------------------------------------------
# gt documentation detaillee au sujet des differents
# less documentation detaillee au sujet des differents [0. 0. 0.]
# --------------------------------------------------
# gt mes respectueuses salutations .
# less mes respectueuses salutations .  [0. 0. 0.]
# --------------------------------------------------
# gt s ' ameliore pas et cela m ' occasionne des troubles du
# less s ' ametiore pas et cela m ' occasionne des troubles des troubles du [0.20588235 0.21428571 1.        ]
# --------------------------------------------------
# gt En vous remerciant par avance de votre comprehension ,
# less En vous remerciant par avance de votre comprehension ,  [0. 0. 0.]
# --------------------------------------------------
# gt l ' expression de mes sinceres salutations .
# less l ' expression de mes sinceres salutations .  [0. 0. 0.]
# --------------------------------------------------
# gt Je vous informe par la presente de mon changement de banque .
# less Je vous informe par la presente de mon changement de banque [0.0483871  0.08333333 1.        ]
# --------------------------------------------------
# gt necessaires ainsi que la liste des documents a
# less necessaires ainsi que la liste des documents a [0. 0. 0.]
# --------------------------------------------------
# gt trop important .
# less tron important .  [0.05882353 0.33333333 1.        ]
# --------------------------------------------------
# gt que cette autorisation s ' obtenait en mairie . Par consequent , auriez
# less que cette autorisation s ' obtenait en marie . Par consequent , aur consequent , aur consequent , , auviez [0.3490566 0.45      1.       ]
# --------------------------------------------------
# gt cadeau obtenu depuis pour mon anniversaire .
# less cadeau obtenu depuis pour mon anniversaire .  [0. 0. 0.]
# --------------------------------------------------
# gt je vous sollicite pour l ' envoi d ' un catalogue . Mon
# less je vous sollicite pour l ' envoi d ' un catalogue . Mon [0. 0. 0.]
# --------------------------------------------------
# gt Je sollicite par cette lettre une remise gracieuse de ma
# less Je sollicite par cette lettre une remise gracieuse de ma [0. 0. 0.]
# --------------------------------------------------
# gt habitation ; dois - je attendre la venue d ' un expert avant d ' entamer
# less habitation ; dois - je attendre la venue d ' un expert avant l ' espert avant l ' enter [0.20689655 0.3        1.        ]
# --------------------------------------------------
# gt ce type de vehicule .
# less ce type de vehicule .  [0. 0. 0.]
# --------------------------------------------------
# gt J ' AIMERAI EGALEMENT ASSURER MA VOITURE
# less J ' AIMERAI EGALEMENT ASSURER MA VOITORE [0.025      0.14285714 1.        ]
# --------------------------------------------------
# gt J ' ai ouvert un compte bancaire dans votre agence le 15 juin
# less J ' ai ouvert un compte bancaire dans votre agence le 15 Jence le 15 Jur [0.20833333 0.25       1.        ]
# --------------------------------------------------
# gt POUVEZ - VOUS ME FOURNIR LA DOCUMENTATION
# less POUVEZ - VOUS ME FOURNIR LA DOCUMENATION [0.02439024 0.14285714 1.        ]
# --------------------------------------------------
# gt le plus tot possible afin de regulariser ma situation .
# less le plus tot possible afin de regulariser ma situation .  [0. 0. 0.]
# --------------------------------------------------
# gt telephoniques seront les suivantes : 03 . 38 . 63 . 49 . 12 .
# less telephoniques les secont les suivantes : 03 . 338 63 . 63 49 . 12 .  [0.16176471 0.3125     1.        ]
# --------------------------------------------------
# gt Je viens de perdre mon emploi et je me retrouve
# less Je viens de perdre mon emploi et je me retrouve [0. 0. 0.]
# --------------------------------------------------
# gt que j ' ai pris chez vous .
# less que j ' ai pris chez vous .  [0. 0. 0.]
# --------------------------------------------------
# gt du materiel de randonnee . Celle - ci contenait un lot de
# less du materil de candonnee . Celle - ci contenait un lot de [0.03508772 0.16666667 1.        ]
# --------------------------------------------------
# gt meilleures salutations .
# less meilleures salutations .  [0. 0. 0.]
# --------------------------------------------------
# gt Mes references client dans votre entreprise sont : FDMGR27
# less Mes references client dans votre entre prise sont : FD HCGRCR027 .  [0.14925373 0.41666667 1.        ]
# --------------------------------------------------
# gt Futur proprietaire d ' une Citroen C6 essence finition exclusive , je vous
# less factur proprietaire d ' une Citroe C6 essence famition es esence fimition excluition exclititition excluiiire ecluiiire , je vo [0.49606299 0.57894737 1.        ]
# --------------------------------------------------
# gt Veuillez agreer , Madame , Monsieur , mes salutations distinguees .
# less Veuillez agreer , Madame , Monsieur , mes salutations distinguees .  [0. 0. 0.]
# --------------------------------------------------
# gt affaire et de m ' en rendre compte .
# less affaire et de m ' en rendre compte .  [0. 0. 0.]
# --------------------------------------------------
# gt les meilleures .
# less les meilleures .  [0. 0. 0.]
# --------------------------------------------------
# gt prospectives d ' avenir .
# less perspect uves d ' avenir .  [0.14814815 0.33333333 1.        ]
# --------------------------------------------------
# gt En effet dernierement j ' ai recu une publicite concernant une
# less En effet dernierement j ' ai recu une publicite concernant une [0. 0. 0.]
# --------------------------------------------------
# gt salutations distinguees .
# less salutations distinguees .  [0. 0. 0.]
# --------------------------------------------------
# gt prie de croire a l ' expression de mes sinceres salutations .
# less prie de croire a l ' expression de mes sinceres salutations .  [0. 0. 0.]
# --------------------------------------------------
# gt Mon lecteur fonctionne tres mal , car le son est tres
# less Mon lecteur fonctionne tres mal , car le son est tres [0. 0. 0.]
# --------------------------------------------------
# gt complementaire .
# less complementaire .  [0. 0. 0.]
# --------------------------------------------------
# gt Je suis actuellement cliente dans votre banque
# less Je suis actuellement cliente dans votre banque [0. 0. 0.]
# --------------------------------------------------
# gt Je viens juste d ' avoir un enfant pour
# less Je venis juste d ' avoir un enfant pour [0.05128205 0.11111111 1.        ]
# --------------------------------------------------
# gt le 3 decembre 2006 est restee sans reponse a ce jour ,
# less le 3 decembre 2006 est restee sans reponse a ce jour ,  [0. 0. 0.]
# --------------------------------------------------
# gt provoque un accident de la route . Ci joint le constat a l '
# less provoque un accident de la route . ci joint le const le constat a l '  [0.14285714 0.1875     1.        ]
# --------------------------------------------------
# gt d ' agreer Madame , Monsieur l ' expression de mes
# less d ' agreer Madame , Monsieur l ' expression de mes [0. 0. 0.]
# --------------------------------------------------
# gt car je viens d ' avoir un enfant , et souhaiterais souscrire
# less car Je viens d ' avoir un enfant , et souhaiterais souscrire [0.01666667 0.08333333 1.        ]
# --------------------------------------------------
# gt voudrez bien me le rembourser .
# less voudrez bien me le rembourser .  [0. 0. 0.]
# --------------------------------------------------
# gt JE RESILIE MON CONTRAT CHEZ VOUS
# less JE RESILE MON CONTRAT CHEZ VOUS [0.03125    0.16666667 1.        ]
# --------------------------------------------------
# gt VOTRE FORFAIT EST TROPS CHER . C ' EST
# less VOTRE FORFAIT ESTROP CHER CHER C EST [0.21052632 0.44444444 1.        ]
# --------------------------------------------------
# gt Je suis interesse par de nombreuses offres de votre enseigne ,
# less je suis interesse par de nombreuses offres de votre enseigne ,  [0.01587302 0.09090909 1.        ]
# --------------------------------------------------
# gt Je tiens a vous signaler par ce courrier que
# less Je tiens a vous signaler par ce courrier que [0. 0. 0.]
# --------------------------------------------------
# gt impot . Vous trouverez ci - joint les photocopies des documents relatifs
# less impot . Vous trouverez ci - joint les photocopres des des documents relatifs [0.06578947 0.15384615 1.        ]
# --------------------------------------------------
# gt pour fournir les pieces necessaires a l ' operation ,
# less pour fournir les precessees a l ' operation ,  [0.18518519 0.2        1.        ]
# --------------------------------------------------
# gt dans vos magasins .
# less dans vos magasions .  [0.04761905 0.25       1.        ]
# --------------------------------------------------
# gt Je vous informe de mon demenagement et vous prie
# less Je vous informe de mon demenagement et vous prie [0. 0. 0.]
# --------------------------------------------------
# gt dater de la presente notification en application de l ' article L . 113 - 16 du
# less dater de la presente rotification en application de s application de l ' artititicicle l t t irticicle L 15 - 16 - 16 16 du [0.3902439 0.5       1.       ]
# --------------------------------------------------
# gt ecrit la commande que je viens d ' effectuer .
# less ecrit la commande que je viens d ' effectuer .  [0. 0. 0.]
# --------------------------------------------------
# gt je reste toutefois joignable par telephone dans le cas ou vous
# less je reste toutefois joignale par telephone dans le cas ou vous [0.01612903 0.09090909 1.        ]
# --------------------------------------------------
# gt En attendant votre reponse , je vous prie
# less En attendant votre reponse , je vous prie [0. 0. 0.]
# --------------------------------------------------
# gt Je vous remercie pour toutes ces annees de confiance et
# less Je vous remercie pour toutes ces annees de confiance et de [0.05172414 0.09090909 1.        ]
# --------------------------------------------------
# gt a ma demande et je vous prie de croire , Madame ,
# less a ma demande et je vous prie de croire , Madame ,  [0. 0. 0.]
# --------------------------------------------------
# gt quels en sont les avantages ?
# less a quels en aont les avantages ?  [0.09375    0.28571429 1.        ]
# --------------------------------------------------
# gt possible , je souhaiterais , en dernier recours
# less possible , je souhaiterais , en dernier recours [0. 0. 0.]
# --------------------------------------------------
# gt numero client est le EULKF25 .
# less numero client est le EULT25 .  [0.06451613 0.16666667 1.        ]
# --------------------------------------------------
# gt POUR CELA QUE PAR CETTE LETTR
# less POUR CELA QUE PAR CETTE LGTTR [0.03448276 0.16666667 1.        ]
# --------------------------------------------------
# gt les donnees personnelles de mon dossier . Je viens en
# less les donnees personnelles de mon dossier . Je viens an [0.01886792 0.1        1.        ]
# --------------------------------------------------
# gt Pourriez - vous prendre en charge ma
# less Pourriez - vous prendre en charge ma [0. 0. 0.]
# --------------------------------------------------
# gt de me rembourser ces trois mois de contrat et de faire en sorte que votre
# ...
# gt Je vous remercie de vous changer de cette
# less Je vous remercie de vous changer de cette [0. 0. 0.]
# --------------------------------------------------
# gt Dans l ' attente de votre reponse , veuillez agreer
# less Dans l ' attente de votre reponse , veuillez agreer [0. 0. 0.]
# --------------------------------------------------
# gt En vous remerciant par avance , je vous prie d ' agreer ,
# less En vous remerciant par avance , je vous prie d ' agreer ,  [0. 0. 0.]
# --------------------------------------------------
# gt une trentaine de kilometres . Je vous laisse mon numero de telephone au cas ou
# less une tientaire de telonites . Je vous laisse mon numero de telephone de telephhhone au ces a [0.27472527 0.35294118 1.        ]
# --------------------------------------------------
# gt Est il possible de m ' envoyer de la documentation
# less Est il possible de m ' envoyer de la documentation [0. 0. 0.]
# --------------------------------------------------
# gt alors que je n ' en ai commande que 20 .
# less alors que je n ' en ai commande que 20 .  [0. 0. 0.]
# --------------------------------------------------
# gt Je n ' arriverai pas a payer en une seule fois .
# less Je n ' arriverai pas a payer en une seule fois [0.06122449 0.08333333 1.        ]
# --------------------------------------------------
# gt Or , je souhaiterais doubler la quantite de CD commandee ,
# less Or , je souhaiterais doubler la quantite de CD commandee ,  [0. 0. 0.]
# --------------------------------------------------
# gt difficultes a payer ma derniere facture . En effet , son montant est
# less difficules a payer ma derniere facture . En effet , son montant est [0.01470588 0.07692308 1.        ]
# --------------------------------------------------
# gt Je vous laisse le soin de choisir pour moi les placements
# less Je vous laisse le soin de choisir pour moi les placements [0. 0. 0.]
# --------------------------------------------------
# gt Cordialement ,
# less Cordialement ,  [0. 0. 0.]
# --------------------------------------------------
# gt 8 Rue du Pinot Noir
# less 8 Rue du Pinst cvoir [0.15 0.4  1.  ]
# --------------------------------------------------
# gt dernier n ' est toujours pas effective .
# less derniers n ' est toujours pas effective .  [0.02380952 0.125      1.        ]
# --------------------------------------------------
# gt JE SUIS ACTUELLEMENT ASSUREE DANS
# less JE SUIS AETVELLEMENT ASSURET DANS [0.09090909 0.4        1.        ]
# --------------------------------------------------
# gt je me retrouve dans l ' impossibilite de payer
# less je me retrouve dans l ' impossibilite de payer [0. 0. 0.]
# --------------------------------------------------
# gt monsieur , mes salutations les plus respectueuses .
# less magreer mes salutations les plus respectueuses .  [0.13461538 0.25       1.        ]
# --------------------------------------------------
# gt Pouvez - vous m ' accorder d ' echelonner mon paiement .
# less Pouvez - vous m ' accorder d ' echelonner mon paiement .  [0. 0. 0.]
# --------------------------------------------------
# gt je desirerais doubler la quantite d ' actions boursiere de cette
# less je desirerais doubler la quantite d ' actions boursiere de cette [0. 0. 0.]
# --------------------------------------------------
# gt de m ' installer bientot : j ' habite a ce jour chez mes parents .
# less de m ' installer bient et , j ' habite a ce jour chez mes parents .  [0.04411765 0.17647059 1.        ]
# --------------------------------------------------
# gt confidentialite et vous adresse mes sinceres salutations distinguees .
# less confilite et vous adresse mes sinceres salutations distinguees .  [0.08450704 0.11111111 1.        ]
# --------------------------------------------------
# gt de la mairie .
# less de de la mairie .  [0.16666667 0.2        1.        ]
# --------------------------------------------------
# gt Code des assurances , par suite d ' augmentation des tarifs .
# less cote des assurances , par suite d ' augmentation des tarifs .  [0.03225806 0.08333333 1.        ]
# --------------------------------------------------
# gt Comptant sur votre comprehension et sur votre
# less comptant sur votre comprehension et sur votre [0.02222222 0.14285714 1.        ]
# --------------------------------------------------
# gt Je vous prie de croire , Madame , Monsieur , a
# less Je vous prie de croire , Madame , Monsieur , a [0. 0. 0.]
# --------------------------------------------------
# gt a vous informer que si vous ne donnez pas suite je
# less a vous informer que si vous ne donnez pas suite je [0. 0. 0.]
# --------------------------------------------------
# gt publicite et aurait besoin de plus d ' informations .
# less publicite et aurait besain de plus d ' informations .  [0.01851852 0.1        1.        ]
# --------------------------------------------------
# gt Merci de votre comprehension .
# less Merci de votre comprehension .  [0. 0. 0.]
# --------------------------------------------------
# gt plus en mesure de realiser de tels versements .
# less plus en misure de realiser de tels versements .  [0.02083333 0.11111111 1.        ]
# --------------------------------------------------
# gt En vous remerciant , veuillez agreer , Madame ,
# less En vous remerciant , veuillez agreer , Madame ,  [0. 0. 0.]
# --------------------------------------------------
# gt cloturer mon compte joint de reference client MZLW079 .
# less celoturer mon compte joint de reference client HX KZZ KZ K2Z N2ZWN099 [0.30434783 0.5        1.        ]
# --------------------------------------------------
# gt Madame , Monsieur , l ' expression de mes salutations
# less Madame , Monsieur , l ' expression de mes salutations [0. 0. 0.]
# --------------------------------------------------
# gt d ' agreer , Madame , Monsieur , l ' expression de mes
# less d ' agreer , Madame , Monsieur , l ' expression de mes [0. 0. 0.]
# --------------------------------------------------
# gt veuillez agreer , Madame , Monsieur , l ' expression de mes salutations
# less Veuillez agreer , Madame , Monsieur , l ' expression de mes salutations [0.01408451 0.07692308 1.        ]
# --------------------------------------------------
# gt 10 ans maintenant je vous fais confiance quant au
# less 10 ans maintenant je vous fais confiance quant au [0. 0. 0.]
# --------------------------------------------------
# gt toutes les depenses liees aux activites proposees par mon ecole .
# less toutes les depenses liees aux activites proposees par mon etale .  [0.03030303 0.09090909 1.        ]
# --------------------------------------------------
# gt sur ma nouvelle voiture ?
# less sur ma nouvelle voiture ?  [0. 0. 0.]
# --------------------------------------------------
# gt Cordialement ,
# less Cordialement ,  [0. 0. 0.]
# --------------------------------------------------
# gt puissiez mettre a jour mes donnees personnelles . Desormais
# less puissiez mettre a jour mes donnees personnelles . Desoisormais [0.0483871  0.11111111 1.        ]
# --------------------------------------------------
# gt pas recu de votre part , confirmation de cette modification
# less pas recu de votre part , confirmation de cette modification [0. 0. 0.]
# --------------------------------------------------
# gt Je souhaiterais donc savoir quels sont les re -
# less Je souhaiterais donc savoir quels sont les re -  [0. 0. 0.]
# --------------------------------------------------
# gt je vous demande de me propose un placement
# less je vous demande de vue proposer un placement [0.06818182 0.25       1.        ]
# --------------------------------------------------
# gt votre envoi de catalogue . J ' ai deja un numero de
# less votre envoi de cetalogue . J ' ai de ja un numero de [0.03846154 0.23076923 1.        ]
# --------------------------------------------------
# gt echelonner mon remboursement ( en m ' accordant donc plus d ' echeances ) afin
# less echelonner mon remboursement ( en m ' accordant donc plus d d ' echeances , afinces , afin [0.14444444 0.22222222 1.        ]
# --------------------------------------------------
# gt Desirant acheter un nouveau telephone portable , je
# less Desirant acheter un nouveau telephone portable , je [0. 0. 0.]
# --------------------------------------------------
# gt J ' attends votre propre confirmation par retour de courrier .
# less J ' attends votre propose confirmation par retour de cour de cour de courrier [0.23376623 0.42857143 1.        ]
# --------------------------------------------------
# gt majeur , je beneficie d ' un bonus d ' un demi point . Ce bonus pourra - t - il s ' appliquer
# less arguer , je beneficie d ' un bonnes d ' un demi paint . Ce bonne pint . Ce bonnes pours poursotiiliel s s ' appliquique [0.35294118 0.46153846 1.        ]
# --------------------------------------------------
# gt sans trop de risque a relatif court terme :
# less saus trop de visque a relatif cout terme :  [0.06818182 0.33333333 1.        ]
# --------------------------------------------------
# gt Cordialement ,
# less Cordialements .  [0.125 1.    1.   ]
# --------------------------------------------------
# gt donc sans revenus . Ayant 3 enfants a charge ,
# less donc sans revenus . Auyant 3 engants a change ,  [0.0625 0.3    1.    ]
# --------------------------------------------------
# gt Je vous remercie par avance pour ces demarches
# less Je vous remercie par avance pour ces demarches [0. 0. 0.]
# --------------------------------------------------
# gt Je souhaite vous commander 3 paires de chaussette referencees
# less Je souhaite vous commander 3 paires de chaussette referencees [0. 0. 0.]
# --------------------------------------------------
# gt Veuillez agreer Madame , Monsieur , mes sinceres
# less Veuillez agreer Madame , Monsieur , mes sinceres [0. 0. 0.]
# --------------------------------------------------
# gt Vous pouvez me joindre au numero suivant : 03 16 42 59 38 .
# less Vous pouvez me joindre au numero suivant : 03 16 16 42 3 59 38 38 38 .  [0.15492958 0.22222222 1.        ]
# --------------------------------------------------
# gt bris du vasistas du grenier ainsi que d ' une dizaine de tuiles .
# less tres du varistes du grenier ainsi que d ' une digatine de tailes .  [0.10447761 0.28571429 1.        ]
# --------------------------------------------------
# gt prelevement de l ' impot sur le revenu et
# less prelevement de l ' infot sur le revenu et [0.04878049 0.11111111 1.        ]
# --------------------------------------------------
# gt Maisonneuve Antoinette
# less Mais enmeuve Antornette [0.17391304 1.         1.        ]
# --------------------------------------------------
# gt je vous prie de bien vouloir tenir compte de mes difficultes
# less je vous prie de bien vouloir tenir compte de mes difficultes [0. 0. 0.]
# --------------------------------------------------
# gt a Oursuer .
# less a Ourour .  [0.16666667 0.33333333 1.        ]
# --------------------------------------------------
# gt apres reflexion je souhaiterais doubler la quantite .
# less apres reflexion je souhaiterais doubler la quantite [0.05555556 0.125      1.        ]
# --------------------------------------------------
# gt Je vous informe que je vends mon vehicule , c ' est pourquoi je
# less Je vous informe que je vends mon vehicule , c ' est pourquoi je [0. 0. 0.]
# --------------------------------------------------
# gt documentation concernant les contrats
# less documentation concernant les contrats [0. 0. 0.]
# --------------------------------------------------
# gt Dans l ' attente que vous m ' envoyez les
# less Dans l ' attente que vous m ' envoyez les [0. 0. 0.]
# --------------------------------------------------
# gt Je vous sollicite , ce jour , pour changer les
# less Je vous sollicite , ce jour , pour changer les [0. 0. 0.]
# --------------------------------------------------
# gt pas d ' honorer , dans l ' immediat , la somme qui m ' est facturee .
# less pas d ' honorer , dans l ' immediat , la somme qui m ' est factuuree .  [0.01408451 0.05555556 1.        ]
# --------------------------------------------------
# gt Ma commande sera donc la suivante , 3 paires de
# less Ma commande sera donc la suivante , 3 pairs de [0.0212766 0.1       1.       ]
# --------------------------------------------------
# gt en date du 15 decembre 2006 , je vous demande de bien vouloir
# less en date du 15 decembre 2006 , je vous demande de bien vouloir [0. 0. 0.]
# --------------------------------------------------
# gt Je trouve inadmessible de n ' avoir recu aucun
# less Je trouve inadmissible de n ' avoir recu aucun [0.02173913 0.11111111 1.        ]
# --------------------------------------------------
# gt traiter ma demande par telephone ; seul un echange de courrier pouvant dans
# less traiter ma demande par telephone , seuil un echange de courrier par de courrier parvant dant dant dans [0.2745098  0.44444444 1.        ]
# --------------------------------------------------
# gt Je vous prie d ' agreer , Madame , Monsieur , l ' expression de mes sentiments
# less Je vous prie d ' agreer , Madame , Monsieur , l ' expression de mes sentimentiments [0.06024096 0.05882353 1.        ]
# --------------------------------------------------
# gt dans les plus brefs delais .
# less dans les plus brefs delais .  [0. 0. 0.]
# --------------------------------------------------
# gt passer a une mensualisation de celui - ci .
# less passer a une mensualisation de celui - ci .  [0. 0. 0.]
# --------------------------------------------------
# gt passant au travers .
# less passant clu travers .  [0.09090909 0.25       1.        ]
# --------------------------------------------------
# gt ayant recemment perdu mon emploi , je sollicite
# less ayant recemment perdu mon emploi , je sollicite [0. 0. 0.]
# --------------------------------------------------
# gt de mes sentiments distingues .
# less de mes sentiments distingues .  [0. 0. 0.]
# --------------------------------------------------
# gt pour que mes prelevements EDF soit honores sur mon nouveau
# less pour ques mes prelevement EDF soit lont Ponces sur mon nouveau [0.12903226 0.36363636 1.        ]
# --------------------------------------------------
# gt Je vous signale egalement que j ' ai fait la conduite anticipee , j ' ai
# less Je vous signale egalement que j ' ai fait la conduile anticipee , j ' ai [0.01388889 0.0625     1.        ]
# --------------------------------------------------
# gt parvenue .
# less parvenue .  [0. 0. 0.]
# --------------------------------------------------
# gt Je vous prie d ' accepter , monsieur , mes plus sinceres
# less Je vous prie d ' accepter , monsieur , mes plus sinceres [0. 0. 0.]
# --------------------------------------------------
# gt est devenu trop important .
# less ostdevenu trol imborhant .  [0.17857143 0.8        1.        ]
# --------------------------------------------------
# gt pour le reglement ( y compris les frais de livraison ) .
# less pour le reglement Cy compris les frais de livraison ) .  [0.03508772 0.16666667 1.        ]
# --------------------------------------------------
# gt mon numero de telephone , qui est le :
# less mon nouveau numero de telephone , qui est le :  [0.17021277 0.1        1.        ]
# --------------------------------------------------
# gt cordialement ,
# less Sordialement ,  [0.06666667 0.5        1.        ]
# --------------------------------------------------
# gt Ma reference client est KLBFS46
# less Ma reference client est XLBF546 [0.06451613 0.2        1.        ]
# --------------------------------------------------
# gt d ' agreer , Madame , Monsieur , l ' expression de mes sentiments
# less d ' agreer , Madame , Monsieur , l ' expression de mes sentiments [0. 0. 0.]
# --------------------------------------------------
# gt Je tiens a votre disposition les objets endommages pour toute expertise
# less Je tiens a votre disposition les dotuges endommages pour tour pour toute expertispertise [0.23863636 0.30769231 1.        ]
# --------------------------------------------------
# gt l ' expression de mon profond respect .
# less l ' expression de mon propond respect .  [0.025 0.125 1.   ]
# --------------------------------------------------
# gt a la modification escomptee
# less a 2a modification soimptee .  [0.24137931 0.6        1.        ]
# --------------------------------------------------

# %%
rem = []
for i,v in enumerate(gt):
    mm = evaluation.ocr_metrics(predicts=[more[i]],
                                  ground_truth=[v])
    nm = evaluation.ocr_metrics(predicts=[predicts[i]],
                                  ground_truth=[v])    
    
    if mm[0]<nm[0]:
        rem.append(i)
        print("gt", v)
        print("more", more[i], mm)
        print("less", predicts[i], nm)
        print("-"*50)
# Out:
# gt echeance le montant verse sur mon PEL soit de 45 euros .
# more echeance le montant vense sur mon PEL sait de 45 euros .  [0.03508772 0.16666667 1.        ]
# less echeance le montant coernse sur mon PEL soit de 45 euros .  [0.05084746 0.08333333 1.        ]
# --------------------------------------------------
# gt d ' un lot de cinquante CD vierges ( reference 010 - 25 - CDV ) .
# more d ' un sot de cirquante CD vierges ( reference 000000 - 25 . CDV ) .  [0.10144928 0.23529412 1.        ]
# less d ' un lot de cinquante CD vierges ( reference 010 - 25 - CD - CD . CD .  [0.12328767 0.25       1.        ]
# --------------------------------------------------
# gt changement de situation . J ' ai en effet donne naissance
# more changement de situation . J ' ai en effet donne naissance [0. 0. 0.]
# less changement de situation . J ' ai en effet donne maissance [0.01754386 0.09090909 1.        ]
# --------------------------------------------------
# gt Madame , Monsieur , de bien vouloir agreer l ' expression des mes sinceres
# more Madame , Monsieur , de bien vouloir agreer l ' expression des mes sinceres [0. 0. 0.]
# less Madame , Monsieur , de bien vouloir agreer l ' expression des mes mes s sincencerenceres [0.15909091 0.1875     1.        ]
# --------------------------------------------------
# gt me compterai alors parmi vos clients .
# more me compterai alors parmivos clients .  [0.02564103 0.28571429 1.        ]
# less me compterai a lors pour mivos clients .  [0.12195122 0.5        1.        ]
# --------------------------------------------------
# gt je me vais oblige de modifier le format des CDs commandes
# more je me vois oblige de modifier le format des CDs commandes ,  [0.06666667 0.16666667 1.        ]
# less je me vais oblige de modifier le formet des CD commandes .  [0.08474576 0.25       1.        ]
# --------------------------------------------------
# gt architecture . J ' ai plus de 20 ans d ' experience dans le metier . Malgre cela ,
# more achitecture . J ' ai plus de 20 ans d ' experence dans le netier . Malgre cela ,  [0.03614458 0.15789474 1.        ]
# less actitere . J ' ai plus de 20 ans d ' experence dans le metierer . Malgre ce ce ce cela , c ce ce a c c c  [0.31428571 0.44827586 1.        ]
# --------------------------------------------------
# gt venez de me livrer , je souhaiterais me faire
# more venez de melivrer , je souhaiterais me faire [0.02222222 0.22222222 1.        ]
# less verez de melivrer , je souhaiterais me faire [0.04444444 0.33333333 1.        ]
# --------------------------------------------------
# gt trois paires de chaussettes ( reference CH45 - 12 ) que j ' ai trouve
# more trois paires de chaussettes ( reference CH45 - 12 ) que j ' ai trouve [0. 0. 0.]
# less trois paires de chaussettes ( reference CH45 - 12 ) que j ' ai t t trouve [0.05479452 0.11764706 1.        ]
# --------------------------------------------------
# gt Vous remerciant du soin que vous apporterez a
# more Vous remerciant du sir que vous apporterez a [0.04444444 0.125      1.        ]
# less Vous remerciant du sur que vous apporterez a [0.06666667 0.125      1.        ]
# --------------------------------------------------
# gt de bien vouloir m ' adresser les informations demandees dans les
# more de bien vouloir m ' adresser les informations demandees dans les [0. 0. 0.]
# less de bien vouloir m ' adresser les informations demandees d dans les les [0.08571429 0.15384615 1.        ]
# --------------------------------------------------
# gt C ' est pourquoi je porte a votre connaissance ma volonte de resilier mon
# more C ' est pousquoi je porte a votre connaissance ma volonte de resilier mon [0.01369863 0.07142857 1.        ]
# less C ' est purquoi je parte a votre connaissance ma volonte de de re re resilier mon [0.13580247 0.29411765 1.        ]
# --------------------------------------------------
# gt Je possede un compte courant dans votre agence depuis plusieurs annees ,
# more Je possede un compte courant dans votre agence depuis plusieurannes ,  [0.04109589 0.16666667 1.        ]
# less Je possede un compte courant dans votre agence depuis plusieur plusierer pus plusierererer derere anes anes ,  [0.35454545 0.41176471 1.        ]
# --------------------------------------------------
# gt utile .
# more intile .  [0.22222222 0.5        1.        ]
# less ville .  [0.375 0.5   1.   ]
# --------------------------------------------------
# gt Je reste a votre disposition pour apporter toute precision
# more Je reste a votre disposition pour apporter toute precuion [0.03448276 0.11111111 1.        ]
# less Je reste a votre disposition pour apporter toute prer toute pre pre precie prie .  [0.32926829 0.46666667 1.        ]
# --------------------------------------------------
# gt Malheureusement , la perte recente de mon emploi de cariste me contraint
# more Malheureusement , la perte recute de mon emploi de cariste me contraint [0.02777778 0.08333333 1.        ]
# less Malheureusement , la perte recente de mon emploi de criste me me con coniste mploi de de con cont me cont cont cont cont [0.43333333 0.58333333 1.        ]
# --------------------------------------------------
# gt Pourriez - vous , s ' il vous plait , envisager un echelonnement de paiement de
# more Pourriee - Vous , s ' il vous plait , envisquer un echelonnement du peiement de [0.07594937 0.3125     1.        ]
# less Pourriez - vous , s ' il vous plait , envisager un echelonnement du du paie pa paun un un un un e e e u e du p pa pa e e e e e [0.4047619  0.63888889 1.        ]
# --------------------------------------------------
# gt je vous ai envoye un courrier il y a plus d ' un mois dans lequel , j ' expliquais
# more je vous ai envoye un courrier il y a plus d ' un mois dans le quel ' expliquais [0.06097561 0.15       1.        ]
# less Je vous ai envoye un courrier il y a plus d ' un mois dans leque j ' e e exprapraiquiqurais [0.16483516 0.28571429 1.        ]
# --------------------------------------------------
# gt la resiliation de mon assurance . Aussi , ce courrier demeure sans
# more la resiliation de mon assurance . Aussuri , ce courrier demeure sans [0.02941176 0.08333333 1.        ]
# less la resiliation de mon assurance . Aussi , ce courrier demene sans [0.03030303 0.08333333 1.        ]
# --------------------------------------------------
# gt mois d ' avril . Je suppose que je beneficierais d ' une petite
# more mois d ' avril . De appose que je beneficierais d ' une petite [0.04761905 0.14285714 1.        ]
# less mois d ' avril . Je appose que je benepierais d ' une pererepicierais d d ' un un un un d d ' un une peicicierai d d d ' d ' u [0.54761905 0.67647059 1.        ]
# --------------------------------------------------
# gt Je vous joint donc mon reglement de 15 , 39 euros sous la
# more Je vous joint donc mon reglement de 15 , 39 euros sous la [0. 0. 0.]
# less Je vous joint donc mon reglement de 15 ) 39 euros s la [0.07017544 0.15384615 1.        ]
# --------------------------------------------------
# gt Hier , en sortant de chez moi , j ' ai malencontreusement marche sur le chien de ma
# more Hier , en serlant de chege mo , j ' aimalencontreusement marhesur le chrhesur le chriesur de ma [0.23157895 0.44444444 1.        ]
# less Ailler , en sertant de chez , j ' ai malencontreusement ment marcheusement ment ment m mar merur lur l l a a a aur l chur ch [0.49193548 0.71428571 1.        ]
# --------------------------------------------------
# gt les mesures qui s ' imposent pour contrer ce fleau sonore que nous
# more les mesures qui s ' imposent pour contrer ce fleau sonore que vous [0.01515152 0.07692308 1.        ]
# less les mesures qui s ' imposent pour contrer ce flean sonore que vous [0.03030303 0.15384615 1.        ]
# --------------------------------------------------
# gt Veuillez acceptez Madame , Monsieur mes excuses pour la gene
# more Veuillez acceptez Madame , Monsieur mes ervuses pour la gene [0.03333333 0.1        1.        ]
# less Veuillez acceptez Madame , Monsieur mes ereuses pour la a a agene [0.10769231 0.33333333 1.        ]
# --------------------------------------------------
# gt mon probleme : inscrite a l ' ANPE depuis six mois , je ne me suis vue proposee
# more mon prbleme - inscrite a 1 ANNE depuis six mois , je ne ne suis vue proporee [0.10126582 0.38888889 1.        ]
# less mon probleme " inscrite a PANCIte depuis sure mois , je ne me suis vis uis uis un un u un pr uis uis uis uis un un une une pre [0.5        0.70967742 1.        ]
# --------------------------------------------------
# gt En effet , mes priorites ont change depuis la naissance
# more En effet . mes prianites ont change depuis la maisrance [0.09090909 0.3        1.        ]
# less En effet , mes promaites ont change depuis la maison l la maissire [0.27272727 0.38461538 1.        ]
# --------------------------------------------------
# gt On y rencontrait constamment plein d ' enfants dans la Rue
# more on y rencontrait constamment plein d ' ergants dans la rue [0.06896552 0.27272727 1.        ]
# less On y rencontrait constamment plain d ' engents d ' engents dans dans lans l d la rgentant dans dans lu lu lu lu lu [0.53508772 0.68       1.        ]
# --------------------------------------------------
# gt Je tiens a vous assurer de ma satisfaction quant a la qualite de
# more Je tiens a vous assurer de ma satisfaction quant a la qualite de [0. 0. 0.]
# less Je tiens a vous assurer de ma satisfaction quant a la quant a la la qualit de [0.19480519 0.29411765 1.        ]
# --------------------------------------------------
# gt Merci de realiser cette operation au
# more Merci de Reca liser cette operation au [0.07894737 0.28571429 1.        ]
# less Merci de recu liser cette operation a un [0.125 0.5   1.   ]
# --------------------------------------------------
# gt de ma reclamation , est restee sans reponse de
# more de ma reclamations , est restee saus reponse de [0.04255319 0.22222222 1.        ]
# less de ma reclamation , est restee sous reponse de [0.04347826 0.11111111 1.        ]
# --------------------------------------------------
# gt ce jour l ' augmentation du trafic rue des Jardins . Autrefois raison -
# more ce saiur l ' augmentation du trafic ue des forduins . Elutorefoison .  [0.22222222 0.42857143 1.        ]
# less ce joint l ' augmentation du trofic mue des ferduires . S S Strardurduis . . C Clulurara . C Cluluraraitis . ra rachais rai [0.53658537 0.72       1.        ]
# --------------------------------------------------
# gt J ' ai l ' honneur de reclamer par la presente la
# more J ' ai l ' honneur de reclamier pour la presentre la [0.07692308 0.25       1.        ]
# less J ' Ai l ' honneur de reclonner pour la presente la [0.11764706 0.25       1.        ]
# --------------------------------------------------
# gt Je me permets par la presente de vous
# more Je me permets par la presente de vous [0. 0. 0.]
# less Je ne permets par la presente de vous [0.02702703 0.125      1.        ]
# --------------------------------------------------
# gt dans une nouvelle ville . Ma ville precedente etait , d ' une part ,
# more dans une nouvelle viclle . Ma ville precedente etait , d ' une pour ,  [0.05714286 0.13333333 1.        ]
# less dans une nouvelle vitre . Ma ville precedente etait , d ' une une pour pout ,  [0.15384615 0.23529412 1.        ]
# --------------------------------------------------
# gt En attendant son effectivite , je vous prie d ' agreer , l ' expression de
# more con attendant con effectuites je vous prie d ' agreer , l ' expression de [0.09459459 0.25       1.        ]
# less En attendant can effectue , je vous prie d ' agreer , l ' exprerererer , l d ' e issurer di d re d ' re re reciore r r io re [0.49193548 0.63636364 1.        ]
# --------------------------------------------------
# gt Province - Alpes - Cote - d ' Azur , je dois naturellement envisager un demenagement
# more Povice - Affre - Cote d ' Ay , je dois ratuellement enviager un demengement [0.17857143 0.4375     1.        ]
# less Pourrice . Afin - Cete - d ' Ayant , je dois rectuellement envont envont ent unvor un un un un un un uroyerager er u u u un un [0.56349206 0.73333333 1.        ]
# --------------------------------------------------
# gt commande . En effet , je souhaite commander 3 paires de chaussettes
# more commende . En effet , je souhaite commander 3 puires de chaussettes [0.02985075 0.16666667 1.        ]
# less commande . En effet , je souhaite connantes 3 puis de chures des 3 puuuis des puis de cha cha de chaier de c c che [0.5        0.65384615 1.        ]
# --------------------------------------------------
# gt Veuillez recevoir , Madame , mes salutations les meilleurs .
# more Veuillez recevoir , Madame , mes salutations les meilleurs .  [0. 0. 0.]
# less Veuillez recevoir , Madame , mes salutations les mes salutations les mes meillllureures .  [0.32222222 0.35714286 1.        ]
# --------------------------------------------------
# gt notification de resiliation dans les plus brefs delais et de proceder au remboursement
# more notiffication de resitiation dans les plus brefs delais et de proceler au remboursement [0.03448276 0.23076923 1.        ]
# less motification de resiliation dans les plus brefs delais et de procele et de procie pro a et de pro de proce de de de pro de de pr [0.3984375  0.67857143 1.        ]
# --------------------------------------------------
# gt Suite a notre conversation telephonique concernant l ' achat
# more Suite a notre conversation telephonique concernant l ' achat [0. 0. 0.]
# less Suite a notre conversation telephonique concernant l ' achanchion l ' anch anchant l l ' achachant l l ' achachat - - acha - a a [0.53125   0.7037037 1.       ]
# --------------------------------------------------
# gt ses de notre contrat mais elle est motivee par une cause
# more ses de votre contrat mais etle est mativee par une cause [0.05357143 0.27272727 1.        ]
# less ses de votre contrat mais elle est mativee par une coure [0.07142857 0.27272727 1.        ]
# --------------------------------------------------
# gt Comptant sur votre comprehension . veuillez recevoir
# more Conotant sur votre commehension , veuillez recevoir [0.09615385 0.42857143 1.        ]
# less Constant sur votre connaitre connaitression , veuillez re recevoilllez r re rece revoiti [0.48863636 0.76923077 1.        ]
# --------------------------------------------------
# gt En effet , mon actuelle compagnie d ' assurance n ' etant pas tres
# more En effet , mon actuelle compagnie d ' assurance n ' etant pas tres [0. 0. 0.]
# less En effet , mon actuelle compagnie d ' assurance n ' etant pas tres pa tres tres [0.16455696 0.17647059 1.        ]
# --------------------------------------------------
# gt livraison de ma commande ne me convient pas , ainsi je souhaite
# more livraison de Ma commande ne Me courrient pas , aumai je souhaite [0.125      0.33333333 1.        ]
# less livraison de Ma commande ne Me convient pas , ainsince je sour , sour - e sour e e souhaircrai e [0.375      0.61904762 1.        ]
# --------------------------------------------------
# gt de mon domicile du 3 Rue Gambetta , 57000 METZ , en date du 28 fevrier
# more de mon domicile du 3 rue Gembettre , 700 MAT0 MAt0 , en tate du 28 fevrier [0.17567568 0.35294118 1.        ]
# less de mon domicile du 3 Rue Gambettan , 5700 MEF , en date du 28 f f f fevrierier d du du 2 du 28 f f f [0.35       0.57142857 1.        ]
# --------------------------------------------------
# gt te entreprise qui a licencie en masse il y a quelques
# more Le extreprise qui a licevacie en moise il y a quelques [0.11111111 0.36363636 1.        ]
# less Le centreprise qui a licencie en moise il y a quelques .  [0.12280702 0.33333333 1.        ]
# --------------------------------------------------
# gt  ( References : 010 - 25 - CDV ) a partir de votre site internet .
# more  ( References : 010 - 25 - CDV ) a partir de votre site internet .  [0. 0. 0.]
# less  ( References : 010 - 25 - CDV ) a partir de votre site intere intere .  [0.08333333 0.11764706 1.        ]
# --------------------------------------------------
# gt Dans l ' attente de votre reponse , je vous prie d ' agreer
# more Dans l ' attente de votre reponse , je vous prie d ' agreer [0. 0. 0.]
# less Dans l ' attente de votre reponse , je vous prie d ' agreeer [0.01666667 0.07142857 1.        ]
# --------------------------------------------------
# gt si possible et commander si possible 6 paires
# more si possible et bominuler si possible 6 paires [0.11111111 0.125      1.        ]
# less si possible et bminarider si postil 6 paires [0.2  0.25 1.  ]
# --------------------------------------------------
# gt j ' ai eu un accident le 13 Mars 2007
# more j ' ai eu un accident le 13 Mars 2007 [0. 0. 0.]
# less j ' ai eu un accident le 13 / nous 2007 [0.12820513 0.18181818 1.        ]
# --------------------------------------------------
# gt lettre est restee sans suite . Je vous ai ecrit le mois dernier
# more letture est restee sans suite . Je vous ai ecrut le mois dernier [0.03125    0.15384615 1.        ]
# less lettre est restee sans suite . Je vous ai ecrit le mois de moi de vous ai ecri l l mois di decrit li [0.38 0.5  1.  ]
# --------------------------------------------------
# gt commander 1 mais 2 paires de chaussettes ref . 1919AB .
# more commander 1 mais 2 paires de chaussettes ref - 109 49 A8 .  [0.10169492 0.30769231 1.        ]
# less commander 1 mais 2 paires de chaussettes ref 10 19 19 19 19 18 18 18 18 18 18 18 18 .  [0.38372093 0.59090909 1.        ]
# --------------------------------------------------
# gt Suite a un degat des eaux subi le 25 fevrier 2007 . Je vous envois tous
# more Suite a un degat der eaux sule 25 fevrier 2007 . Je vous envais tous [0.07042254 0.25       1.        ]
# less Suite a un degat des eaux suble le 25 fevrier 2007 . Je vous vous e e envous enais enais envai ai cous envai cous e [0.4 0.5 1. ]
# --------------------------------------------------
# gt changement n ' ayant pas ete pris en compte , je me permets
# more changement n ' ayant pas ete pris en compte , je me permets [0. 0. 0.]
# less changement n ' auyant pas ete pris en compte , je me permets [0.01666667 0.07692308 1.        ]
# --------------------------------------------------
# gt m ' adresser votre documentation concernant les contrats
# more m ' adresser votre documentation concernant les contrats [0. 0. 0.]
# less m ' adresser votre documentation concernant les concernant les contres cont cont cont cont cont cont cont contrt cont cont cont [0.56692913 0.66666667 1.        ]
# --------------------------------------------------
# gt Pourriez - vous y remedier rapidement afin que mon
# more Pourriez - vous y remedier rapidement afinique mon [0.02       0.22222222 1.        ]
# less Pourriez vous j remedier rapidement afinique mon [0.08       0.44444444 1.        ]
# --------------------------------------------------
# gt la fourniture de 250 paires de chaussettes , je me
# more la fourniture de 250 paires de chaussettes , je me [0. 0. 0.]
# less la journiture de 250 paires de chaussettes , je me [0.02 0.1  1.  ]
# --------------------------------------------------
# gt Si vos prix sont attractifs et vos contrats attrayants , vous
# more Sivos prir sont attractifs et vos contrats attragants , vous [0.04918033 0.36363636 1.        ]
# less Si vos prin sont attractifs et vos contrats attraguants , vous vous [0.11940299 0.25       1.        ]
# --------------------------------------------------
# gt stock disponible se revele nettement insuffisant a repondre a la demande ,
# more stact disponible serevelle rettement insuffisant a reprondre a 6a demande ,  [0.09210526 0.5        1.        ]
# less etocte disposible se revelle nettement insuffisant acre repependre ant re a repopondrendre a a a a a repore dre a e e epoe dr [0.464      0.79166667 1.        ]
# --------------------------------------------------
# gt Ci - joint mon nouveau numero 06 . 17 . 27 . 32 . 27
# more joint mon nouveau numero 06 . 17 . 29 . 27 [0.21153846 0.33333333 1.        ]
# less joint mon nouveau numero 06 . 17 . 23 . 73 . 73 . 73 . 717 [0.31034483 0.52941176 1.        ]
# --------------------------------------------------
# gt et je vous prie de croire que jamais je ne vous aurais demande cette
# more et je vous prie de moine que jomais je ne vous aurai demarde cette [0.08823529 0.28571429 1.        ]
# less et je vous prie de noire que je nais je ne vous aurai demai de demande ci demande ci ci de de ci derai de [0.42857143 0.6        1.        ]
# --------------------------------------------------
# gt generales du contrat . Je vous prie , par ailleurs , de me faire parvenir une
# more generales du contrat . Je vous prie , par ailleurs , de me faire parvenir une [0. 0. 0.]
# less geneales du contrat . Je vous prie , par ailleurs , de me faire pair par par ar ails ci de de de me de me fai [0.36697248 0.51851852 1.        ]
# --------------------------------------------------
# gt Je vous prie de bien vouloir agreer , Madame , Monsieur , mes sinceres
# more Je vous prie de bien vouloir agreer , Madame , Monsileur , mes sinceres [0.01408451 0.07142857 1.        ]
# less Je vous prie de bien vouloir agreer , Madame , Monsieur , mes sincererer , , mes s sincencerer c cererer ,  [0.34579439 0.40909091 1.        ]
# --------------------------------------------------
# gt au mieux ma future visite a votre agence .
# more au mieux ma future visite a votre agence .  [0. 0. 0.]
# less au mieux ma facture visite a votre agence .  [0.04545455 0.11111111 1.        ]
# --------------------------------------------------
# gt votre magazine et au lieu de les acheter tous les
# more votre magagine et au lieu de les acheter tous les [0.02040816 0.1        1.        ]
# less votre magazine et au vieu de les acheter vous les [0.04081633 0.2        1.        ]
# --------------------------------------------------
# gt Je soussignee MATEI Adele vous recontacte suite a un courrier
# more Je soussignee HATEI Adele vous recontacte suite a un courrier [0.01639344 0.1        1.        ]
# less Je soussignee MATEI Adele vous recontacte suite a un courite a un couite a un uit un uit a uit uite a uit un un c uit a un vui [0.53174603 0.7        1.        ]
# --------------------------------------------------
# gt VHDEP71 .
# more UHEPO71 .  [0.3 0.5 1. ]
# less VHopotos .  [0.54545455 0.5        1.        ]
# --------------------------------------------------
# gt Suite a mon courrier precedent , j ' attendais des explications de votre part
# more Suite a mon courries precedent , j ' attendais des ex explications de votre part [0.05       0.13333333 1.        ]
# less Suite a mon courrier precedent , j ' attendais des es explications dis des es es explicicaticatitions dion di de de de de de d [0.43650794 0.52       1.        ]
# --------------------------------------------------
# gt Recevez , Messieurs , mes salutations les plus distinguees .
# more Recevez , Mersieurs , mes salutations les les lus distingueeres .  [0.10606061 0.36363636 1.        ]
# less Recevez , Messieurs , mes salutations les les s salutations dions dis .  [0.27777778 0.38461538 1.        ]
# --------------------------------------------------
# gt commande .
# more conande .  [0.18181818 0.5        1.        ]
# less conurande .  [0.25 0.5  1.  ]
# --------------------------------------------------
# gt Vous remerciant de prendre en compte ma commande , je vous prie ,
# more Vous remerciant de prendre en compte ma commande , je vous prie ,  [0. 0. 0.]
# less Vous remerciant de prendre en compte ma commande , je vous pris pr ,  [0.05797101 0.14285714 1.        ]
# --------------------------------------------------
# gt de saisir la repression des fraudes .
# more de soisir la repression des frandes .  [0.05263158 0.28571429 1.        ]
# less de soisir la repression des frandes frandes .  [0.2173913 0.375     1.       ]
# --------------------------------------------------
# gt proposez semblent repondre parfaitement
# more proposez sembleut repandre parfaitement [0.05128205 0.5        1.        ]
# less proposez seuls leut repondre parfaitement [0.12195122 0.4        1.        ]
# --------------------------------------------------
# gt d ' un trajet avec mon automobile , j ' ai percute le vehicule
# more d ' un trajet aue mon automobile , j ' ai farente le vilicale [0.14516129 0.21428571 1.        ]
# less d ' un troyit avc mon automobile , j ' ai precente le citi licile [0.23076923 0.33333333 1.        ]
# --------------------------------------------------
# gt Apres avoir fait l ' acquisition d ' un home cinema il y a deux semaines , il
# more Apres avoir fait l ' ocquisition d ' un home cineme il y a deux semaines , il [0.02597403 0.11111111 1.        ]
# less Apres avoir foit l ' acquisition d ' un home cheme il y a deux s seme s semeiner , , emenc , , a [0.29166667 0.44       1.        ]
# --------------------------------------------------
# gt de mon enfant .
# more de mun enfant [0.25 0.5  1.  ]
# less de nun enfant [0.3125 0.5    1.    ]
# --------------------------------------------------
# gt avoir bientot de vos nouvelles
# more avoir bientot de vos nouvelles [0. 0. 0.]
# less avoir bientiot de vos nouvelles [0.03225806 0.2        1.        ]
# --------------------------------------------------
# gt son humanite et saura aider une famille a repartir a zero .
# more son Remanite et saura acceler ene famille a repartic a eero .  [0.14516129 0.41666667 1.        ]
# less son remarite et saura aicler une famille a reportie a set re .  [0.17460317 0.38461538 1.        ]
# --------------------------------------------------
# gt Lors d ' un entretien , l ' un de vos conseiller m ' avait parle d ' une assurance vie .
# more Lors d ' un entratier , l ' un de vot conseiller m ' avait parde d ' une assurance vie .  [0.04494382 0.13636364 1.        ]
# less Lors d ' un entretien , l ' en de vos conseiller m ' avait part d d ' un un un avairaititit dit paititit d d d ' d u u u u u un [0.4015748  0.55555556 1.        ]
# --------------------------------------------------
# gt un accident de la circulation le 11 Mars 2007 a Forbach .
# more un accident de la circulation le 11 Mers 2007 a fortact .  [0.06896552 0.16666667 1.        ]
# less un accident de la circulation le 111 Te007 207 a Fort .  [0.18965517 0.33333333 1.        ]
# --------------------------------------------------
# gt JE ME PERMETS DE VOUS ECRIRE POUR AVOIR
# more JE ME PERMET DE VOUS ECRIRE POUR AVOir [0.07692308 0.25       1.        ]
# less JE ME PERMET DE VOUS ECRIRE POUROUR POUR AvOIr [0.23913043 0.33333333 1.        ]
# --------------------------------------------------
# gt concernant les contrats d ' assurance habitation de votre compagnie .
# more concernant les contrats d ' assurance habitation de votre compagnie .  [0. 0. 0.]
# less concernant les contrats d ' assurance habitation de votre compagie .  [0.01428571 0.09090909 1.        ]
# --------------------------------------------------
# gt complications j ' ai du demenager et j ' habite donc maintenant
# more complications J ' ai dul demenager et j ' habite donc maintenant [0.03125    0.16666667 1.        ]
# less complications . j ' ai dui demenager et j ' habite donc main maintenant [0.11267606 0.21428571 1.        ]
# --------------------------------------------------
# gt Mon courrier du 7 fevrier 2007 , dans lequel , je vous faisais part
# more Mon courrier du 7 fevrier 2007 , dans lequel , je vous faisais part [0. 0. 0.]
# less Mon courrier du 2 fevrier 2007 , dans lequet , je vous faisaisais pais part [0.13333333 0.26666667 1.        ]
# --------------------------------------------------
# gt AUTOMOBILE
# more AUTOMPLABILE [0.25 1.   1.  ]
# less AVTOMBIL [0.3 1.  1. ]
# --------------------------------------------------
# gt La qualite de vos produits satisfaisant pleinement la clientele , mon
# more La qualite de vos produits satisfaisant pairement la cllentele , mon [0.05797101 0.18181818 1.        ]
# less La qualite de vos produits satisfaisant pleirement la a a attententele , , mon [0.16666667 0.35714286 1.        ]
# --------------------------------------------------
# gt au lieu de 10 CD
# more au lieu de 10 CD [0. 0. 0.]
# less au lien de 10 CD [0.0625 0.2    1.    ]
# --------------------------------------------------
# gt Je vous remercie tout d ' abord pour l ' efficacite mise en oeuvre par
# more Je vous remercie tout d ' alorel porel l ' efficacite mise en oeuvre par [0.08333333 0.13333333 1.        ]
# less Je vous remercie tout d ' atteral pour l ' efficacite mise mise en s en seuvit pa par [0.24705882 0.31578947 1.        ]
# --------------------------------------------------
# gt de 6 mois dont j ' aimerais assurer l ' avenir s ' il devait m ' arriver quelque chose .
# more de 6 mois dont j ' aimerais assurer l ' avenir s ' il devait m ' anver quelquechore .  [0.05617978 0.14285714 1.        ]
# less de 6 mois dont j ' aimerais assurer l ' avenir s ' il devail m ' arvail m quer quelqucccchitie quec .  [0.19607843 0.26086957 1.        ]
# --------------------------------------------------
# gt Je m ' adresse a vous en ce jour du 01 mars 2007 pour vous faire
# more Me n ' adresse a vous on ce jour du 01 mors 2007 pour vous faire [0.0625 0.25   1.    ]
# less Je m ' adresse a vous en ce jour du est mois 2007 pour vous f vous far vour f vour f vour f f f pour vour f f vour f f f  [0.52066116 0.61764706 1.        ]
# --------------------------------------------------
# gt Avec mon conjoint , nous allons nous installer
# more Avec mon conjoint , nous allons nous nous installer [0.09803922 0.11111111 1.        ]
# less Avec mon conjoint , nous alons nous ilons nous installer [0.17857143 0.3        1.        ]
# --------------------------------------------------
# gt service dont j ' ai beneficie jusqu ' ici . Je vous prie , Madame , Monsieur ,
# more service dont j ' ai beneficie jusqu ' ai . Je vous prie , Madame , Monsieur ,  [0.02531646 0.05555556 1.        ]
# less service dont j ' ai beneficie jusqu ' ci . Je vous prie , de vous prire , , Madidandame , di Mon di di , Monier dier dier dier d [0.421875   0.51612903 1.        ]
# --------------------------------------------------
# gt au lieu de 30 .
# more aue eieu de 30 .  [0.11764706 0.4        1.        ]
# less au ereu dete 30 .  [0.22222222 0.4        1.        ]
# --------------------------------------------------
# gt modification .
# more mudisficution .  [0.1875 0.5    1.    ]
# less modificute an .  [0.25       0.66666667 1.        ]
# --------------------------------------------------
# gt J ' avais alors decline son offre . Neanmoins , j ' ai maintenant un petit garcon
# more J ' avais alons decdire son effre . Neanmoins , j ' ai maintenant en putit garces [0.09876543 0.35294118 1.        ]
# less J ' avais alons decture son offre . Meaimaine , j ' ai maintentenant ant u u u u pa parcri erai erai enai e e e c c c p ' p ' [0.472      0.70588235 1.        ]
# --------------------------------------------------
# gt Etant actuellement assuree par une compagnie differente de la votre
# more Etant actuellement assuree par une compagnie differente de la votre [0. 0. 0.]
# less Etant actuellement assuree par une compagnie differente de de la votre de de la votr [0.20238095 0.33333333 1.        ]
# --------------------------------------------------
# gt d ' un changement de coordonnees personnelles . En effet ,
# more d ' un changement de coordonnees personnelles . En effet ,  [0. 0. 0.]
# less d ' un changement de coordonnees personnelles . En effet , , en en efffet ,  [0.22368421 0.3125     1.        ]
# --------------------------------------------------
# gt ma Ford Fiesta , immatriculee
# more ma Ford Fieste , innatriculee [0.10344828 0.4        1.        ]
# less ma Ford Ford Fiesta , immatriculee [0.14705882 0.16666667 1.        ]
# --------------------------------------------------
# gt plus garant :
# more plus garant :  [0. 0. 0.]
# less plus garant .  [0.07142857 0.33333333 1.        ]
# --------------------------------------------------
# gt d ' agreer , Madame , Monsieur , mes salutations
# more d ' agreer , Madame , Monsieur , mes salutations [0. 0. 0.]
# less d ' agreer , Madame , Monsieur , mes salutations .  [0.05882353 0.09090909 1.        ]
# --------------------------------------------------
# gt Je vous pris d ' agree , monsieur , mes
# more Je vous pris d ' agree , monsieur , mes [0. 0. 0.]
# less Je vous pris d ' agreer , monsieur , mes [0.025 0.1   1.   ]
# --------------------------------------------------
# gt l ' expression de ma consideration .
# more l ' expression de mes consideration .  [0.05263158 0.14285714 1.        ]
# less l ' expression de ma coinderation .  [0.08108108 0.14285714 1.        ]
# --------------------------------------------------
# gt occasionee ainsi que l ' expression de mes sinceres salutations .
# more accosionnee ainsi que l ' expression de mes sinceres salutations .  [0.04477612 0.09090909 1.        ]
# less accordonnee ainsi que l ' expression de mes sinceres salutions .  [0.10606061 0.18181818 1.        ]
# --------------------------------------------------
# gt Je vous saurai gre de bien vouloir me faire parvenir un devis
# more Je vous saurai gre de bien vouloir me faire parvenir un devois [0.01612903 0.08333333 1.        ]
# less Je vous saurai agre de bien vouloir me faire parvenir un devoi [0.0483871  0.16666667 1.        ]
# --------------------------------------------------
# gt La cloture ne prend pas effet immediatement , mais a compter du 01 / 03 / 2007 .
# more et at cleture re prudquon effe imedsatement , mais a compter du 01 / 05 / 006 .  [0.22222222 0.5        1.        ]
# less Et a cette re pour effet immediantement , mais a compter du du du du 0 du 01 01 / cois a a compt der du du du du du du d [0.56666667 0.75       1.        ]
# --------------------------------------------------
# gt Par consequent , je veux etre rembourse dans les
# more Par consequent , je veux etre rembourse dans les [0. 0. 0.]
# less Bar consequent , je veux etre rembourse dans les [0.02083333 0.11111111 1.        ]
# --------------------------------------------------
# gt Recevez , Madame , Monsieur , l ' assurance de mes sentiments
# more Recevez , Madame , Monsieur , l ' assurance de mos sentiments [0.01639344 0.08333333 1.        ]
# less Recevez , Madame , Monsieur , l ' assurance de mes s sentiments [0.03174603 0.07692308 1.        ]
# --------------------------------------------------
# gt contre le meme en blanc dont la reference est CH 45 - 16 . Je vous retourne
# more contre le mememe en en blanc dont la reference est 01 - 10 - 16 . Je vous retourne [0.13414634 0.26315789 1.        ]
# less contre le meme en blanc dont la refierence est cit 0 - 45 - 15 - 16 . . 6 . 6 . 76 . . 7 . a a etous retoure retoure [0.40517241 0.63636364 1.        ]
# --------------------------------------------------
# gt Devant demenager sous peu , je prospecte afin de trouver la
# more Devant demenager sous peu , je prospeche afin de trouver la [0.01694915 0.09090909 1.        ]
# less Devant demenager sous par , je propecte afin de trouver la [0.05084746 0.18181818 1.        ]
# --------------------------------------------------
# gt paiements differes , en les echelonnant sur 4 mois ?
# more paiements differes , en les echelonnant sur 4 mois ?  [0. 0. 0.]
# less paiements differes , ens les echelonnant sur 4 mois ?  [0.01851852 0.1        1.        ]
# --------------------------------------------------
# gt sur l ' efficacite de vos services . J ' aurais ici besoin que vous me couvriez au titre de
# more sur l ' efficacite de vos services . J ' auvais cabesoin que vous me courriez au titu de [0.07692308 0.25       1.        ]
# less sur l ' effecte de vos services . J ' avais cachoranque que voue vous me vous me me cous cous me cous me cous m cou m m cou cou [0.51181102 0.64516129 1.        ]
# --------------------------------------------------
# gt Neanmoins , etant donnee ma nouvelle affectation professionnelle en region
# more Neanmoins , etant donnee ma nouvelle affectation professionnelle en refin [0.02702703 0.1        1.        ]
# less Necmmoins , etant donnee ma nouvelle affectation professionnnellle e e en en r r r refi i .  [0.25       0.61111111 1.        ]
# --------------------------------------------------
# gt le contrat d ' assurance habitation souscrit pour ma maison pour cause de vente de ce bien
# more le contrat d ' assuance habitation surait pour ma maison pour cause de vents de ce bui [0.1        0.23529412 1.        ]
# less le contrat d ' assurance habitation suvrait pour ma ma ma maison pour pour pour cur cur dur de de de de vous de de de von de de [0.4015748 0.5862069 1.       ]
# --------------------------------------------------
# gt Comme indique dans les conditions particulieres de mon contrat d ' assurance
# more Comme indique dans les conditions particulieres de mon contrat d ' assurance [0. 0. 0.]
# less Comme indique dans les conditions particuliees de mon con contr contrtrat de de de mon con con contrere a a a avecous .  [0.44166667 0.69565217 1.        ]
# --------------------------------------------------
# gt Etant interessee par vos produits , pourriez - vous m ' envoyer
# more Etant interessee par vos produits , pourriez - vous m ' envoyer [0. 0. 0.]
# less Etant interessee par vos produits , pourriez - vous m ' en vous m ' envoy - en voy .  [0.27058824 0.45       1.        ]
# --------------------------------------------------
# gt aussi imprevue que penible pour moi .
# more aussi imprevie que perible pour maci .  [0.1025641  0.42857143 1.        ]
# less aussi imprevue que persible pour mieux .  [0.14634146 0.28571429 1.        ]
# --------------------------------------------------
# gt aucun poste correspondant a mon profil . J ' ai 52 ans et je suis diplomee en
# more aucon poste Grespondant a mon profil . J ' ai 3 ans et je suis diplonee ex [0.1038961  0.29411765 1.        ]
# less aucun poste correspondant a mon prof . J ' ai 32 ans ans e et j sui ai s ans s ans sus dis dis depererais di di [0.41441441 0.60714286 1.        ]
# --------------------------------------------------
# gt m ' est apparu indispensable de changer de canape et j ' ai donc achete un
# more m ' est appanu indisgensable de changer de concpe et j ' ai donc achete un [0.05405405 0.1875     1.        ]
# less m ' est apparu indispenseble de changer de commer de conc pe et j ' ai d d ' ai d donc a a ai a a ai doche a a che ache a che [0.456      0.65714286 1.        ]
# --------------------------------------------------
# gt Si je vous ecris , c ' est donc dans l ' espoir que vous saurez prendre
# more cli je vous ecris , c ' est donc dans l ' esprir que vous sourez prendre [0.05555556 0.17647059 1.        ]
# less ete je vous ecris , c ' est donc dans l ' expair que vous s saurez pre vous s s saurez prendrez prendre [0.34951456 0.375      1.        ]
# --------------------------------------------------
# gt composee de cinq pieces principales .
# more composee de cinq pieces principales .  [0. 0. 0.]
# less composee de cing pieces principales .  [0.02631579 0.16666667 1.        ]
# --------------------------------------------------
# gt Dans l ' attente d ' une reponse de votre part , je vous prie de croire , Madame ,
# more Dans l ' attente d ' une reponse de votre part , je vous prie de croire , udame ,  [0.02409639 0.05       1.        ]
# less Dans l ' attente d ' une reponse de votre part , je vous prie de de crie crou dre donconc donc doncont de de de de de de de de [0.3968254  0.48387097 1.        ]
# --------------------------------------------------
# gt courrier est jusqu ' a aujourd ' hui reste sans reponse . Le
# more courrier est jusqu ' a aujourd ' hui reste sans reponse . Le [0. 0. 0.]
# less courrier est jusqu ' a a aujourd ' hui reste sans reponse . Le [0.03225806 0.07142857 1.        ]
# --------------------------------------------------
# gt performante dans les actions a realiser , je souhaiterai vivement
# more pertemente dans les actions a resaliser , je souhaiterai vivement [0.07692308 0.2        1.        ]
# less pertimante dans les actions a realiser , je souhaiterai vi vivement [0.08955224 0.18181818 1.        ]
# --------------------------------------------------
# gt Madame , Monsieur l ' expression de mes salutations les meilleures .
# more Madame , Monsieur d ' expression de mes salutations les meilleures [0.05797101 0.16666667 1.        ]
# less Madame , Monsieur l ' expression de mes salutations mes meilleureures [0.07246377 0.25       1.        ]
# --------------------------------------------------
# gt Je viens par la presente vous dire mon Nornement .
# more Je viens pour la presente vous dire mon ehonnement .  [0.09433962 0.2        1.        ]
# less Je viens par la presente vous due mon ertonnement .  [0.11538462 0.2        1.        ]
# --------------------------------------------------
# gt BWKQY25
# more BUKQXY125 [0.33333333 1.         1.        ]
# less BUROY25 [0.42857143 1.         1.        ]
# --------------------------------------------------
# gt au contrat d ' assurance auto n 585 V 18 souscrit
# more au contrat d ' assurance auto n 55 V 18 souscrit [0.02040816 0.09090909 1.        ]
# less au contrat d ' assurance auto n 55 V18 souscrit [0.04081633 0.27272727 1.        ]
# --------------------------------------------------
# gt Je vous ecris pour vous faire part de mon mecontentement . En effet ,
# more Je vous ecris pour vous faire part de mon necontentement . En effet ,  [0.01428571 0.07142857 1.        ]
# less Je vous ecris pour vous faire part de mon mecontentement . En en efffet ,  [0.05405405 0.13333333 1.        ]
# --------------------------------------------------
# gt courrier , de vous notifier mes nouvelles coordonnees bancaires . Dans ce but ,
# more courrier , de vous modifier mes nouvelles vodonnees bancaires . Dance but ,  [0.0875     0.28571429 1.        ]
# less courrier , de vous modifier mes nouvelles vordonnees bancaires . : Dans Dans . Dans cans cans cans cans ca ca caie ca ca ce [0.43089431 0.64       1.        ]
# --------------------------------------------------
# gt bien vouloir facturer les commandes de charbon sur mon nouveau compte
# more bien vouloir freture les commandes de chacton sur mes nouveau compte [0.10144928 0.27272727 1.        ]
# less bien vouloir prectuer les commandes de chausser sur mon c n n nouveaus cous cierer an c c cour c cour courer c c cour cour cou [0.53968254 0.74074074 1.        ]
# --------------------------------------------------
# gt Je vous prie de bien vouloir prendre acte de ma volonte de resilier a reception de la presente
# more Je vous prie de bien voulai prendr ce de ma dont . de ma de resilier a reception , de la preception , de la prese [0.30973451 0.5        1.        ]
# less Je vous prie de bien vouloir prendre conte de ma vodont - ie ilie a u u un restititier a actitititier a a a a c c cececicicer [0.408      0.64285714 1.        ]
# --------------------------------------------------
# gt je vous prie de croire , Monsieur le maire , en l ' expression de mon
# more je vous prie de croire , Monsieur le maire , en l ' expression de mon [0. 0. 0.]
# less je vous prie de voire , Monsieur le maire , en l ' expression dion de m [0.12676056 0.17647059 1.        ]
# --------------------------------------------------
# gt donc gre de me confirmer la reception de cette
# more presente lettre , aivoir que la modification de mes donnees  [0.65 0.8  1.  ]
# less presente lettre , ainsi que la modification de mes donnies de mes dons donnies [0.73076923 0.85714286 1.        ]
# --------------------------------------------------
# gt Je reste a votre disposition pour tout renseignements complementaires .
# more Je reste a votre disposition pour tout renseignements complementaires .  [0. 0. 0.]
# less Je reste a votre disposition pour tout reseignements complements complement coment compl cous complouent coue .  [0.40178571 0.5        1.        ]
# --------------------------------------------------
# gt qui jouaient a diverses activites . De plus , je me disputais
# more qui jouaient a diverses acturites . De plus , je me disputais [0.03278689 0.08333333 1.        ]
# less qui jourdient a diverses actuites . De plus , je me dispoutais [0.08064516 0.25       1.        ]
# --------------------------------------------------
# gt En esperant que ma plainte soit entendue et prise en consideration ,
# more En esperant que ma plainite soit entendue et prise en consideration ,  [0.01428571 0.08333333 1.        ]
# less En esperant que ma plainte soit rentendue et prise en etendure et prise en et prise e en en en con dide e e en con coide de dera [0.5078125  0.68965517 1.        ]
# --------------------------------------------------
# gt tenir au courant rapidement .
# more terir au cousant rapidement .  [0.06666667 0.4        1.        ]
# less terier au consant rapidement .  [0.12903226 0.4        1.        ]
# --------------------------------------------------
# gt a compter du 1er avril 2007 .
# more a compter du 1er avril 2007 .  [0. 0. 0.]
# less a compter du 1en aril 2007 .  [0.06666667 0.28571429 1.        ]
# --------------------------------------------------
# gt Ayant recemment change mon ordinateur et donc mon graveur ,
# more Ayant , recemment change mon ordinateur et donc mon graver ,  [0.04918033 0.18181818 1.        ]
# less Ayant recemment change mon ordirateur et donc mon grateur et donc mon mon gra mon grouveur ,  [0.35483871 0.52941176 1.        ]
# --------------------------------------------------
# gt Ou mais voila , il me reste encore 58 mensualites a regler sur ma nouvelle
# more ou mais voilta , il me reste encore s8 mensualiter a regler sur me nouveller sur me nouvelle [0.23913043 0.44444444 1.        ]
# less Ai mois voits , il me reste encore 3 mensualiter a refler sur sur ur men nsulilititer a a a a r r uur a reflititi - i ur ur ur u [0.5390625 0.78125   1.       ]
# --------------------------------------------------
# gt Peugeot 407 break et j ' ai quelques difficultes a finir mes mois .
# more Pauget 40t bratre et j ' ai quelquer difficultes a finir mes may .  [0.16176471 0.35714286 1.        ]
# less Byent 407 bref et j ' ai quelquer difficultes a fin mes mes m mes moi .  [0.26388889 0.47058824 1.        ]
# --------------------------------------------------
# gt au nom de ORY Pascale ( Reference client : EXOXU51 ) .
# more au nom de ORp Pascale Freference clientiEXOW51 .  [0.2        0.58333333 1.        ]
# less au nom de OP Passale preference client Z [0.36363636 0.66666667 1.        ]
# --------------------------------------------------
# gt Veuillez agreer , Madame , Monsieur , l ' expression de mes salutations
# more Veuillez agreer , Madame , Monsieur , l ' expression de mes salutations [0. 0. 0.]
# less Veuillez agreer , Madame , Monsieur , l ' expression de mes s ssion de mes s ssilun ssion de de me s salutututution de de [0.42975207 0.53846154 1.        ]
# --------------------------------------------------
# gt Md Dubois je souhaiterais etre couvert au titre de la responsabilite
# more Nd D Dhois . Je souhaiterais etre cas vut su titre de la resonsabilite [0.2        0.64285714 1.        ]
# less N D Debutours . Je souhaiterais etre couvrit au titre de la re couvert tit du tititit de du de la tititititie de e de de de de [0.56349206 0.78571429 1.        ]
# --------------------------------------------------
# gt EN EFFET , JE COMPTE CHANGER D ' ASSURANCE C ' EST
# more EN EFFET , JE ( COUMPTE CHANGER D ' ASSURQURADURZ CE CEST [0.22807018 0.5        1.        ]
# less EN EFFET , jE COMPE CANTE CAUSCR D ' ASSURACRI A ASSURURCR A C C CSURUR C C C CSSUR C A C C C CSTAT C CIT CT C CIT CT T T [0.66942149 0.82352941 1.        ]
# --------------------------------------------------
# gt Pour cela je vous remercie de bien vouloir
# more Pour cela je vous remercie de bien vouloir [0. 0. 0.]
# less Pour celui je vous remercie de bien vouloir [0.04651163 0.125      1.        ]
# --------------------------------------------------
# gt merci de votre collaboration
# more mercion de votre collaloration [0.1 0.5 1. ]
# less remercian de votre collaboration [0.125 0.25  1.   ]
# --------------------------------------------------
# gt Vous remerciant par avance de l ' interet
# more Vous remer quiant par avance de l ' uiteret [0.11627907 0.33333333 1.        ]
# less Vous remer qu ' ant par avance de l ' initeret [0.15217391 0.45454545 1.        ]
# --------------------------------------------------
# gt que je vous ai commandee etait insuffisante .
# more que je vous ai commandee etait insuffisante .  [0. 0. 0.]
# less que je vous ai commandee etait muffisaite .  [0.08695652 0.125      1.        ]
# --------------------------------------------------
# gt profond respect .
# more profond respect .  [0. 0. 0.]
# ...
# --------------------------------------------------
# gt voisine . Celle - ci , tenant beaucoup a son chien , a ete particulierement affectee par l ' accident
# more voisine . Celle - ci , terancoupa son chien , a ete portualierement affecte par l ' accident [0.12871287 0.25       1.        ]
# less voire . Celle - i , tenant bancoup a son chien , a ete prortrtrachuatie , e e echichit eement ent e tafee pa pa pa pa a a a [0.42276423 0.63333333 1.        ]
# --------------------------------------------------
# gt  ( n 900 AA ) date du 8 mars 2007 . Je voudrai modifier
# more  ( n 900 44 ) date du 8 mars 2007 . Je voudrai modifier [0.03636364 0.07142857 1.        ]
# less  ( n y000 ) date du 8 mars 2007 . Je voudrai modifier [0.07272727 0.14285714 1.        ]
# --------------------------------------------------
# gt Je viens par ce courier , arreter mon contrat
# more Je viens pour ce courier , Arneter mon contrat [0.08695652 0.22222222 1.        ]
# less Je viens par ce courier , Anneler mon contrat [0.08888889 0.11111111 1.        ]
# --------------------------------------------------
# gt sion de mes salutations les meilleures .
# more dions de mes salutations les meilleures .  [0.04761905 0.14285714 1.        ]
# less otions de mes salutations les meilleures .  [0.06976744 0.14285714 1.        ]
# --------------------------------------------------
# gt situee trop loin de mon travail mais etait aussi trop bruyante .
# more situele trop loin de mon travail mais etait ausoi trop brujante .  [0.04545455 0.25       1.        ]
# less situee tros loin de mon travail mais etait aussi trop brusi brou .  [0.11940299 0.23076923 1.        ]
# --------------------------------------------------
# gt Je souhaite donc que vous procediez a la resiliation de mon contrat
# more Je souhaite donc que vous procediez a la resiliation de mon contrat [0. 0. 0.]
# less Je souhaite donc que vous procediez a la resiliation de mon con con con contrtr -  [0.20731707 0.3125     1.        ]
# --------------------------------------------------
# gt Je vous prie d ' agreer , Madame , Monsieur , mes meilleures salutations .
# more Je vous prie d ' agreer , Madame , Monsieur , mes meilleures salutations [0.04       0.06666667 1.        ]
# less Je vous prie d ' agreer , Madame , Monsieur , mes meilleurer s salutions s [0.08 0.25 1.  ]
# --------------------------------------------------
# gt une demande d ' information concernant la possibilite de re - evaluation
# more une demande d ' information concernant la possibilite de recevhhhation [0.08333333 0.25       1.        ]
# less une demande d ' information concernant la possibilite de re re recevorororororatiatition [0.21590909 0.16666667 1.        ]
# --------------------------------------------------
# gt CTJMI 19 .
# more CTJHIN 19 .  [0.16666667 0.33333333 1.        ]
# less CT JHIT 19 .  [0.23076923 0.5        1.        ]
# --------------------------------------------------
# gt magnifique canape d ' angle en cuir rouge , du plus bel effet dans mon salon
# more magnifique conpe d ' ange en caus raye , du plus be effet dens mon selan .  [0.21052632 0.47058824 1.        ]
# less magnifice canape d ' ergle en cie rouge , du plus tous effet dans mon mon mon s sololoi .  [0.3  0.45 1.  ]
# --------------------------------------------------
# gt le plus rapidement possible , une notification de
# more le plus rapidement possible , une notiffication de [0.02  0.125 1.   ]
# less le plus rapidement possible , une modification de [0.04081633 0.125      1.        ]
# --------------------------------------------------
# gt n ' etes pas sous connaitre les difficultes que traverse cet -
# more n ' etes pas sous connaitre les difficultes que traverse cet -  [0. 0. 0.]
# less n etes pas saus connaitre les difficultes que traverse ce cet [0.11111111 0.33333333 1.        ]
# --------------------------------------------------
# gt Je vous adresse le present courrier afin de vous informer a nouveau
# more Je vous adresse le present caurrier afin de vous informer a naureau [0.04477612 0.16666667 1.        ]
# less Je vous adresse le present courrier afin de vous in de vous inforerer a a nfin de de vous i [0.31868132 0.5        1.        ]
# --------------------------------------------------
# gt Vous en remerciant , recevez mes
# more Vous en remerciant , recevez mes [0. 0. 0.]
# less Vous en remer cient , recevez mes [0.06060606 0.28571429 1.        ]
# --------------------------------------------------
# gt pour un prelevement excessif , il semblerait que vos services
# more pour un prelevement excessif , il semblerait que vos services [0. 0. 0.]
# less pour un prelevement exccesif , il semblerait que vos services [0.03278689 0.1        1.        ]
# --------------------------------------------------
# gt requete , je vous prie d ' agreer Madame , Monsieur , l ' expression de mes
# more requete , je vous prie d ' agreer Madame , Monsieur , l ' expression de mes [0. 0. 0.]
# less requete , je vous prie d ' agreer Madame , Monsieur , l ' expression dion di me messssion dion dion d de m me me me d me me [0.3902439  0.46666667 1.        ]
# --------------------------------------------------
# gt Effectivement , je me suis avancee apres un STOP , et avec le
# more Effectivement , je me suis avance apres un soroe , et avec le [0.09836066 0.15384615 1.        ]
# less Effectuement , je me suis avance apres un strois , et avec le [0.14754098 0.23076923 1.        ]
# --------------------------------------------------
# gt J ' aimerais enfin avoir une reponse ou du moins connaitre les raisons de
# more J ' aimerais entis avoir une reponse ou du moins connaitre les naisons de [0.04109589 0.14285714 1.        ]
# less J ' aimerais entin avoir une reponse ou des moins connaitre les les rais r des rais conconconconcitititre lt le le le le de [0.43089431 0.54166667 1.        ]
# --------------------------------------------------
# gt tient a vous informez de ma volonte de rectifie cette
# more tient a vous informez de ma volonte derntifie cette [0.05660377 0.2        1.        ]
# less tient a vous informer de ma volonte derntifie cette [0.0754717 0.3       1.       ]
# --------------------------------------------------
# gt bleu , mais le coloris ne convient pas . Je souhaite donc echanger cet article
# more lleur , mais le coloris ne convient pas . Je souhaite donc changer cet artile [0.05128205 0.2        1.        ]
# less Plus , mais le calois ne convient pas . Je souhaite donc echanc e et e donc echan er changr c cet c cet ct a ct art art a et et [0.46456693 0.65625    1.        ]
# --------------------------------------------------
# gt C ' est avec beaucoup de plaisir que l ' an dernier j ' ai recu de votre
# more C ' est avec beaucoup de plaisin que l ' an dernier j ' ai rez aivoin [0.125      0.22222222 1.        ]
# less C ' est avec beaucoup de plasir que l ' an dernier j ' ai reci d d ' recirererair dire dire di di dire di d re [0.4 0.5 1. ]
# --------------------------------------------------
# gt parvenir vos tarifications et conditions d ' adhesion concernant vos contrats
# more parvenir vos tarifications et condetions d ' adhession concernant vos contrats [0.02564103 0.18181818 1.        ]
# less parvenir vos tarifications et conditions d ' adression concien conconcernt concent vont cont conconcent cent vent ant vont ant [0.42857143 0.63157895 1.        ]
# --------------------------------------------------
# gt d ' assurances concurrente , j ' ai pris connaissance de vos
# more d ' assurances concurrente , j ' ai pris connaissance de vos [0. 0. 0.]
# less d ' assurances concurrente , j ' ai pris connaissance de de vos [0.04761905 0.07692308 1.        ]
# --------------------------------------------------
# gt remplir les documents necessaires a mon affiliation .
# more remplir les documents necessaires a mon affeliation .  [0.01851852 0.125      1.        ]
# less remplin les documents necessaires a mon affetion .  [0.09259259 0.25       1.        ]
# --------------------------------------------------
# gt 4448 CJ 25
# more 4L458 - J5 95 [0.46153846 1.         1.        ]
# less 448 CDJ [0.5 1.  1. ]
# --------------------------------------------------
# gt habitation n DPUET36 , je souhaite vous faire part de mon recent demenagement
# more habitation n DOTVT36 , je souhaite vous faire pert de mon recaut demagement [0.1038961  0.30769231 1.        ]
# less habitation n DIVTI30 , je souhaite vous faire part de mon re recien de mon r recin a vous ci ci eci ent de de de c eci deci deci [0.46875    0.66666667 1.        ]
# --------------------------------------------------
# gt Suite a la naissance de mon enfant , je souhaiterais
# more Suite a la naissance de mon enfant , je souhaiterais [0. 0. 0.]
# less Suite a la maissance de mon enfant , je souhaiterais [0.01923077 0.1        1.        ]
# --------------------------------------------------
# gt nablement frequentee , ce sont aujourd ' hui des dizaines de camions
# more moblement frequentee , ce sont ausourd ' hui des digaimes de comions [0.08823529 0.33333333 1.        ]
# less moblement frequentee , ce sont auscourd ' hui des dijoines des des des dejoines des des de deroiraires de de de de couioure de [0.53174603 0.66666667 1.        ]
# --------------------------------------------------
# gt Je prendrais ma decision , a reception des differentes offres que
# more Je prendrais ma decision , a reception des differentes offres que [0. 0. 0.]
# less Je prendrais ma decision , a reception des differentes ofion des offres ques que [0.1875     0.21428571 1.        ]
# --------------------------------------------------
# gt C ' est pourquoi , je souhaite modifier la quantite demandee : soit 60 packs
# more C ' est pourquoi , je souhaite modifier la quantite demandee . soit 60 paches [0.03896104 0.13333333 1.        ]
# less C ' est pourquoi , je souhaite modifier la quantite demande - soit de demandondeee - - soitoit - soit t toit t ait a a a [0.425      0.59259259 1.        ]
# --------------------------------------------------
# gt Je reste a votre entiere disposition pour des rensei -
# more Je reste a votre entiere disposition pour des Renseir -  [0.03571429 0.1        1.        ]
# less Je reste a votre entiere disposition pour des Rensei [0.07272727 0.2        1.        ]
# --------------------------------------------------
# gt En esperant que ma requete obtienne satis -
# more En esperant que ma requete obtieaine satis .  [0.06666667 0.25       1.        ]
# less En esperant que ma requete oblitenue satis .  [0.08888889 0.25       1.        ]
# --------------------------------------------------
# gt les quantites d ' un des produits commandes . Je ne desire plus
# more les quantites d ' un des produits commandes . Je ne desire plus [0. 0. 0.]
# less les quantites d ' un des produits commandes . Je ne desire plire plusire plusire pl plusi . . Je ne ne de desire plire plire pl [0.50393701 0.55555556 1.        ]
# --------------------------------------------------
# gt En effet , depuis plusieurs mois , les difficultes financieres ne cessait
# more En effet , cepuis plosieurs mois , les difficulles financieres ne ressant [0.06849315 0.33333333 1.        ]
# less En effet , depuis plusieurs mois , les difficultes financieres nes ne ne ne n a ass ass ant [0.21978022 0.42105263 1.        ]
# --------------------------------------------------
# gt du mois d ' avril prochain .
# more du mois d ' avoil prochain .  [0.03448276 0.14285714 1.        ]
# less du mois d ' avil quochain .  [0.10344828 0.28571429 1.        ]
# --------------------------------------------------
# gt mes tres sinceres salutations .
# more mes tres denceres salutations , .  [0.11764706 0.33333333 1.        ]
# less mes Ares sence salutations .  [0.15625 0.4     1.     ]
# --------------------------------------------------
# gt Veuillez agreer Madame , Monsieur , l ' expression de mes sentiments
# more Veuillez agreer Madame , Monsieur , l ' expression de mes sentiments [0. 0. 0.]
# less Veuillez agreer Madame , Monsieur , l ' expression de mes s sentimentiments [0.09333333 0.15384615 1.        ]
# --------------------------------------------------
# gt Je vous prie d ' aggreer , Madame , Monsieur , mes meilleures salutations .
# more Je vous prie d ' aggreer , Madame , Monsieur mes meilleures salutations .  [0.02631579 0.06666667 1.        ]
# less Je vous prie d ' aggreer , Madame , Monsieur , mes mes meilleures s s meillureures s s s s meiluilluilueueututieureureueure [0.44715447 0.40909091 1.        ]
# --------------------------------------------------
# gt sentiments distingues .
# more sentiments distingues .  [0. 0. 0.]
# less rentments destingues .  [0.125      0.66666667 1.        ]
# --------------------------------------------------
# gt C ' est pour cette raison que je vous ecris afin de vous demander
# more C ' est pour cette raison que je vous ecris afin de vous demander [0. 0. 0.]
# less C ' est pour cette raison que je vous ecris afin de vous de vous deman demander [0.17721519 0.17647059 1.        ]
# --------------------------------------------------
# gt Etant assuree chez vous depuis de nombreuses annees , je sais que l ' on peut compter
# more Etant assurchez vous depuis de nembreuses annees , je saisque l ' ompeut compier [0.09411765 0.47058824 1.        ]
# less Etant assurechez - vous depuis de nombreuses annees , je suisuis l ' re suisuis quis l l l ' suisuisquisque que l l l l ' ais [0.464      0.64285714 1.        ]
# --------------------------------------------------
# gt 60 actuels . Merci d ' appliquer cette modification a compter
# more 60 actuels . Merci d ' appliquer cette modification a compter [0. 0. 0.]
# less 60 actuels . Merci d ' appliquer cette modification a comption a a co compti a co com co com compti a a a co co co com a co co [0.53174603 0.67741935 1.        ]
# --------------------------------------------------
# gt Je suis cliente de vos services depuis de nombreuses annees .
# more Je suis cliente de vos services depuis de nombreuves annees .  [0.01612903 0.09090909 1.        ]
# less Je suis cliente de vos services depuis de nombreuser anneees .  [0.03174603 0.18181818 1.        ]
# --------------------------------------------------
# gt d ' une quantite importante de CD vierges pour divers usages
# more L ' une quantite importante de CD vierges pour divers usages [0.01666667 0.09090909 1.        ]
# less L ' une quantite importante de CD vierges pour divers mages [0.05       0.18181818 1.        ]
# --------------------------------------------------
# gt compte au sein de votre societe d ' assurance .
# more compte au sein de votre societe d ' assurance .  [0. 0. 0.]
# less compte au jein de votre societe d ' assurance .  [0.02083333 0.1        1.        ]
# --------------------------------------------------
# gt Je n ' ai , a ce jour , toujours pas recu la moindre reponse de votre
# more Je n ' ai , a ce jour , toujours pas recu la moindu reponse de votre [0.02898551 0.05882353 1.        ]
# less Je n ' ai , a ce jour , toujours pas recu la moindre re reponse de de votre [0.08       0.10526316 1.        ]
# --------------------------------------------------
# gt de s ' accumuler au point que mon endettement est devenu trop important
# more de saccemuler au point que mon endettement est devenu trop inportant [0.07042254 0.30769231 1.        ]
# less de n ' accunder au point que mon endettement est devenu t trop devenu t t t devenu t t t t deux t t devenu t t t truenu t t t [0.52      0.6969697 1.       ]
# --------------------------------------------------
# gt Merci -
# more Merci -  [0. 0. 0.]
# less Merci .  [0.125 0.5   1.   ]
# --------------------------------------------------
# gt le revenu . Je souhaite , a partir de ce jour , opter pour
# more le revenu . Je souhaite , a partir de a jour , opter pour [0.03448276 0.07142857 1.        ]
# less le revenu . Je souhaite , a partir de ce jour , opter pour pour pour [0.14705882 0.125      1.        ]
# --------------------------------------------------
# gt Je voudrais modifier avant l ' expedition
# more Je voudrais modifier XVant l ' expedition [0.04878049 0.14285714 1.        ]
# less Je voudrais modifier suront l ' expedition [0.0952381  0.14285714 1.        ]
# --------------------------------------------------

# %%
len("mon conseiller AVE ne propose que des emplois sous que diffies .")
# Out:
# 64

# %%
len(rem)
# Out:
# 239

# %%
from PIL import Image, ImageOps
import numpy as np

"""
Creates an augmented image by applying Random warp grid distortion.
This is based on/inspired by
Wigington, Curtis, et al. 
"Data Augmentation for Recognition of Handwritten Words and Lines Using a CNN-LSTM Network." 
Document Analysis and Recognition (ICDAR), 2017 14th IAPR International Conference on. 
Vol. 1. IEEE, 2017.
"""

class GD(object):
    def __init__(self, prob=0.7, gridsize=(26, 26), deviation=1.7):
        self.probability = prob
        self.gridsize = gridsize
        self.deviation = deviation

    def __call__(self, sample):
        image = sample
        if np.random.rand() < self.probability:
            image = _warp(image, self.gridsize, self.deviation)
        return image

def RandomWarpGridDistortion(images, count, gridsize, deviation):
    new_images = []
    for image in images:
        new_images.extend([_warp(image, gridsize, deviation)
                           for i in range(count)])
    images.extend(new_images)
    return images


def _warp(img, gridsize=None, deviation=None, mat=None, return_mat=False):
    gridsize = gridsize or (26, 26)
    deviation = deviation or 10
    (w, h) = img.size

    num_x = w // gridsize[0] + 1
    num_y = h // gridsize[1] + 1

    mat = mat if mat is not None else np.random.normal(
        scale=deviation, size=(num_y + 1, num_x + 1, 2))

    mesh = []
    for x in range(num_x):
        for y in range(num_y):
            target = (x * gridsize[0], y * gridsize[0],
                      (x + 1) * gridsize[0], (y + 1) * gridsize[0])
            nw_y = y * gridsize[0] + mat[y, x, 0]
            nw_x = x * gridsize[0] + mat[y, x, 1]

            sw_y = (y + 1) * gridsize[0] + mat[y + 1, x, 0]
            sw_x = x * gridsize[0] + mat[y + 1, x, 1]

            se_y = (y + 1) * gridsize[0] + mat[y + 1, x + 1, 0]
            se_x = (x + 1) * gridsize[0] + mat[y + 1, x + 1, 1]

            ne_y = y * gridsize[0] + mat[y, x + 1, 0]
            ne_x = (x + 1) * gridsize[0] + mat[y, x + 1, 1]

            source = (nw_x, nw_y, sw_x, sw_y, se_x, se_y, ne_x, ne_y)

            mesh.append((target, source))

    img_transformed = img.transform(
        img.size,
        method=Image.MESH,
        data=mesh,
        fillcolor=255)

    if return_mat:
        return img_transformed, mat
    else:
        return img_transformed

# %%
im = Image.open("../raw/iam/lines/b01/b01-000/b01-000-00.png")

# %%
im.transpose
# Out:
# <bound method Image.transpose of <PIL.PngImagePlugin.PngImageFile image mode=L size=1620x85 at 0x7F87F3C10B20>>

# %%
# Out:
# array([[244, 251, 251, ..., 255, 255, 255],
#        [251, 251, 251, ..., 255, 255, 255],
#        [251, 251, 250, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
gg = _warp(Image.fromarray(cv2.transpose(np.array(im))), deviation=2.7)

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1620x85 at 0x7FA5DFD67430>

# %%
img = pp.preprocess("../raw/iam/lines/b01/b01-000/b01-000-00.png", input_size=(1024,128,1))

# %%
def pre(path, input_size):
    img = cv2.imread(path, cv2.IMREAD_UNCHANGED)
    wt, ht, _ = input_size
    h, w = img.shape
    f = max((w / wt), (h / ht))
    new_size = (max(min(wt, int(w / f)), 1), max(min(ht, int(h / f)), 1))

    img = cv2.resize(img, new_size)
    img = pp.illumination_compensation(img)
#     img = pp.remove_cursive_style(img)
    img = cv2.resize(img, new_size)
    target = np.ones([ht, wt], dtype=np.uint8) * 255
    target[0:new_size[1], 0:new_size[0]] = img
    return target

# %%
img = pre("../raw/washington/data/line_images_normalized/277-06.png", input_size=(1024,128,1))

# %%
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FCA44588C10>

# %%
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FCA44588A30>

# %%
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FCA3546F5B0>

# %%
dataset = {}
with h5py.File("../data/bentham.hdf5", "r") as f:
    dataset["valid"] = dict()

    dataset["valid"]['dt'] = np.array(f["valid"]['dt'])
    dataset["valid"]['gt'] = np.array(f["valid"]['gt'])

# %%
Image.fromarray(cv2.transpose(np.repeat(dataset["valid"]['dt'][35][..., np.newaxis],3, -1) ))
# Out:
# <PIL.Image.Image image mode=RGB size=1024x128 at 0x7F0C68C4C340>

# %%
cv2.transpose(img)

# %%
import json
# with open("pre.json","w") as f:
#     json.dump(less+ more, f)
    
with open("pre.json","r") as f:
    a= json.load(f)

# %%
1542//2
# Out:
# 771

# %%
less = a[:771]

# %%
more = a[771:]

# %%
source = "../data/rimes.hdf5"
split = "train"

# %%
dataset = dict()

with h5py.File(source, "r") as f:
    dataset[split] = dict()

    dataset[split]['dt'] = np.array(f[split]['dt'])
    dataset[split]['gt'] = np.array(f[split]['gt'])

    randomize = np.arange(len(dataset[split]['gt']))
    np.random.seed(42)
    np.random.shuffle(randomize)

    dataset[split]['dt'] = dataset[split]['dt'][randomize]
    dataset[split]['gt'] = dataset[split]['gt'][randomize]

    # decode sentences from byte
    dataset[split]['gt'] = [x.decode() for x in dataset[split]['gt']]

# %%
len(dataset[split]['dt'])
# Out:
# 10114

# %%
from PIL import Image

# %%
for i,v in enumerate(dataset[split]['gt']):
    if "ne quantite importante de" in unicodedata.normalize("NFKD", v).encode("ASCII", "ignore").decode("ASCII"):
        print(i)
#     Image.fromarray(cv2.transpose(dataset["test"]["dt"][1]))
# Out:
# 761

# %%
gt[769], predicts[769]
# Out:
# ('le revenu . Je souhaite , a partir de ce jour , opter pour',
#  'le revenu . Je souhaite , a partir de ce jour , opter pour')

# %%
Image.fromarray(cv2.transpose(dataset["test"]["dt"][769]))
# Out:
# <PIL.Image.Image image mode=L size=1024x128 at 0x7F06C481A430>

# %%
tokenizer.encode('ai réglé régulièrement les intérêts .')
# Out:
# array([ 2, 14, 22, 98, 31, 18, 20, 25, 18, 98, 31, 18, 20, 34, 25, 22, 18,
#        31, 18, 26, 18, 27, 33, 98, 25, 18, 32, 98, 22, 27, 33, 18, 31, 18,
#        33, 32, 98, 79,  3])

# %%
tokenizer.decode([ 2, 14, 22, 98, 31, 18, 20, 25, 18, 98, 31, 18, 20, 34, 25, 22, 18,
       31, 18, 26, 18, 27, 33, 98, 25, 18, 32, 98, 22, 27, 33, 18, 31, 18,
       33, 32, 98, 79,  3])
# Out:
# 'SOSai regle regulierement les interets . EOS'

# %%
img = cv2.imread("../raw/iam/lines/b01/b01-000/b01-000-00.png")

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
img.shape, gray.shape
# Out:
# ((140, 1856, 3), (140, 1856))

# %%
im = pp.preprocess("../raw/iam/lines/a04/a04-000/a04-000-00.png", (1024, 128, 1))

# %%
imm = pp.remove_cursive_style(gray)

# %%
cv2.imwrite("temp.png",imm)
# Out:
# True

# %%
im.shape
# Out:
# (1024, 128)

# %%
a = torch.rand(1,3,1024,128)

# %%
get_feature(r,a).shape
# Out:
# torch.Size([1, 512, 32, 4])

# %%
import timm

# %%
a = timm.create_model('resnest101e', pretrained=False)

# %%
a
# Out:
# ResNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): ResNestBottleneck(
#       (conv1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Identity()
#         (1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResNestBottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (2): ResNestBottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): ResNestBottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (avd_last): AvgPool2d(kernel_size=3, stride=2, padding=1)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): AvgPool2d(kernel_size=2, stride=2, padding=0)
#         (1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResNestBottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (2): ResNestBottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (3): ResNestBottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): ResNestBottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (avd_last): AvgPool2d(kernel_size=3, stride=2, padding=1)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): AvgPool2d(kernel_size=2, stride=2, padding=0)
#         (1): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (2): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (3): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (4): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (5): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (6): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (7): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (8): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (9): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (10): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (11): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (12): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (13): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (14): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (15): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (16): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (17): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (18): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (19): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (20): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (21): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (22): ResNestBottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): ResNestBottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (avd_last): AvgPool2d(kernel_size=3, stride=2, padding=1)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): AvgPool2d(kernel_size=2, stride=2, padding=0)
#         (1): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResNestBottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (2): ResNestBottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): SplitAttn(
#         (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#         (bn0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act0): ReLU(inplace=True)
#         (fc1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): ReLU(inplace=True)
#         (fc2): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (rsoftmax): RadixSoftmax()
#       )
#       (bn2): Identity()
#       (act2): Identity()
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#   )
#   (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
import glob
import numpy as np

# %%
a = glob.glob("raw/iam/forms/*")

# %%
Bottom=1790
Left=375
Right=2044
Top=748

# %%
with Image.open("raw/iam/forms/a01-000x.png") as pil_img:
    img = np.array(pil_img)
img = img[Top:Bottom + 1, Left:Right + 1]
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=L size=1670x1043 at 0x7F3D6E792970>

# %%
pil_img.size
# Out:
# (2479, 3542)
